# %%
from pymongo import MongoClient
import pandas as pd
import re
import requests


client = MongoClient('mongodb://localhost:27017/')
db = client.company

# %%
#filter companies that have coordinates

query= db.company.find({
    "$and":
    [
     {"offices.longitude":{"$exists":True}},
     {"offices.latitude":{"$ne":None}},
     {"offices.longitude":{"$ne":None}},
     {"offices.longitude":{"$exists":True}
     }
    ]
}
)

# %%
print(query)
# Out:
# <pymongo.cursor.Cursor object at 0x126d62d68>

# %%
with_coords = pd.DataFrame(query)
with_coords.head(2)
# Out:
#                         _id  \
# 0  52cdef7c4bab8bd675297d8a
# 1  52cdef7c4bab8bd675297d8b
#
#                                          acquisition acquisitions  \
# 0  {'price_amount': 30000000, 'price_currency_cod...           []
# 1                                               None           []
#
#            alias_list                     blog_feed_url  \
# 0                      http://digitalquarters.net/feed/
# 1  Zoho ManageEngine
#
#                       blog_url category_code  \
# 0  http://digitalquarters.net/           web
# 1                                 enterprise
#
#                                         competitions           created_at  \
# 0  [{'competitor': {'name': 'Wikia', 'permalink':...  2007-05-25 06:51:27
# 1                                                 []  2007-05-25 19:24:22
#
#                                 crunchbase_url  ...  phone_number  \
# 0   http://www.crunchbase.com/company/wetpaint  ...  206.859.6300
# 1  http://www.crunchbase.com/company/adventnet  ...  925-924-9500
#
#                                             products  \
# 0  [{'name': 'Wikison Wetpaint', 'permalink': 'we...
# 1                                                 []
#
#                                        providerships  \
# 0                                                 []
# 1  [{'title': 'DHFH', 'is_past': True, 'provider'...
#
#                                        relationships  \
# 0  [{'is_past': False, 'title': 'Co-Founder and V...
# 1  [{'is_past': True, 'title': 'CEO and Co-Founde...
#
#                                          screenshots  \
# 0  [{'available_sizes': [[[150, 86], 'assets/imag...
# 1  [{'available_sizes': [[[150, 94], 'assets/imag...
#
#                                             tag_list total_money_raised  \
# 0  wiki, seattle, elowitz, media-industry, media-...             $39.8M
# 1                                                                    $0
#
#    twitter_username                    updated_at  video_embeds
# 0   BachelrWetpaint  Sun Dec 08 07:15:44 UTC 2013            []
# 1      manageengine  Wed Oct 31 18:26:09 UTC 2012            []
#
# [2 rows x 42 columns]

# %%
#new dataframe with filtered columns

with_coords2 = with_coords[['_id','name','number_of_employees','category_code','offices','founded_year','ipo','funding_rounds','total_money_raised','investments','deadpooled_year','partners']]
with_coords2.head(100)
with_coords2.shape
# Out:
# (9025, 12)

# %%
get_offices= pd.DataFrame(with_coords['offices'].tolist()).stack().reset_index(level=1, drop=True)
office = get_offices.rename('office')

office.head()
# Out:
# 0    {'description': '', 'address1': '710 - 2nd Ave...
# 0    {'description': '', 'address1': '270 Lafayette...
# 1    {'description': 'Headquarters', 'address1': '4...
# 2    {'description': 'Headquarters', 'address1': '4...
# 3    {'description': None, 'address1': '135 Mississ...
# Name: office, dtype: object

# %%
df_clean= with_coords2.merge(office, left_index= True, right_index=True)

df_clean[['name','number_of_employees','category_code','office','ipo','total_money_raised','deadpooled_year','partners']]
# Out:
#                                 name  number_of_employees     category_code  \
# 0                           Wetpaint                 47.0               web
# 0                           Wetpaint                 47.0               web
# 1                          AdventNet                600.0        enterprise
# 2                               Zoho               1600.0          software
# 3                               Digg                 60.0              news
# 4                           Facebook               5299.0            social
# 4                           Facebook               5299.0            social
# 4                           Facebook               5299.0            social
# 5                            Postini                  NaN               web
# 6                               Geni                 18.0               web
# 7                            Flektor                  NaN       games_video
# 8              Fox Interactive Media                  0.0               web
# 9                            Twitter               1300.0            social
# 10                            Gizmoz                  NaN               web
# 11                            Scribd                 50.0              news
# 12                           Slacker                  NaN             music
# 13                              Lala                  NaN       games_video
# 14                             Helio                  NaN            mobile
# 15                              eBay              15000.0               web
# 16                           MeetMoi                 15.0            social
# 17                             Joost                  0.0       games_video
# 18                               CBS                  NaN              news
# 19                            Viacom                  NaN               web
# 20                          Babelgum                  NaN       games_video
# 21                             Plaxo                 50.0               web
# 22                             Cisco              63000.0   network_hosting
# 23                            Yahoo!              13600.0               web
# 24                          Powerset                 60.0            search
# 25                        Technorati                 35.0       advertising
# 26                            Mahalo                 40.0               web
# ...                              ...                  ...               ...
# 8996                 Luminus Devices                  NaN             other
# 8997                Chestnut Medical                  NaN           biotech
# 8998              Emrise Corporation                  NaN          hardware
# 8999                          Nellix                  NaN              None
# 9000                      Hellocoton                  4.0             other
# 9001                      AwardSpace                 35.0   network_hosting
# 9002                       Buddhacom                  8.0            search
# 9003                     Atlantic BT                 30.0               web
# 9004                        SEO Sumo                  5.0  public_relations
# 9005                        InstantQ                  3.0       advertising
# 9006                        NextLabs                100.0        enterprise
# 9007                       acrossair                  6.0            mobile
# 9008                  Cameron Health                  NaN           medical
# 9009                        Cantimer                  NaN              None
# 9010         Celestial Semiconductor                  NaN     semiconductor
# 9011                        Purfresh                  NaN         cleantech
# 9012                       MyChances                  2.0        consulting
# 9012                       MyChances                  2.0        consulting
# 9013                 InSound Medical                  NaN           biotech
# 9014                          Getyoo                 10.0            mobile
# 9015                  EnterSys Group                  NaN          software
# 9016                  Axon Solutions                  NaN          software
# 9017                         Intergy                  NaN          software
# 9018                   Willdan Group                385.0             other
# 9019  Contemporary Computer Services                  NaN          software
# 9020                            QSGI                164.0          software
# 9021                          Oriact                  NaN          software
# 9022                      AfterLogic                  NaN          software
# 9023             EnteGreat Solutions                  NaN          software
# 9024                       EnteGreat                  NaN        enterprise
#
#                                                  office  \
# 0     {'description': '', 'address1': '710 - 2nd Ave...
# 0     {'description': '', 'address1': '270 Lafayette...
# 1     {'description': 'Headquarters', 'address1': '4...
# 2     {'description': 'Headquarters', 'address1': '4...
# 3     {'description': None, 'address1': '135 Mississ...
# 4     {'description': 'Headquarters', 'address1': '1...
# 4     {'description': 'Europe HQ', 'address1': '', '...
# 4     {'description': 'New York', 'address1': '340 M...
# 5     {'description': None, 'address1': '959 Skyway ...
# 6     {'description': 'Headquarters', 'address1': '9...
# 7     {'description': None, 'address1': '8536 Nation...
# 8     {'description': '', 'address1': '407 N Maple D...
# 9     {'description': '', 'address1': '1355 Market S...
# 10    {'description': None, 'address1': None, 'addre...
# 11    {'description': 'HQ', 'address1': '539 Bryant ...
# 12    {'description': '', 'address1': '16935 W. Bern...
# 13    {'description': 'Lala Headquarters', 'address1...
# 14    {'description': None, 'address1': '10960 Wilsh...
# 15    {'description': 'Headquarters', 'address1': '2...
# 16    {'description': None, 'address1': '', 'address...
# 17    {'description': '', 'address1': '100 5th Ave F...
# 18    {'description': None, 'address1': '', 'address...
# 19    {'description': 'HQ', 'address1': '1515 Broadw...
# 20    {'description': '', 'address1': '', 'address2'...
# 21    {'description': 'HQ', 'address1': '1050 Enterp...
# 22    {'description': 'Headquarters', 'address1': '1...
# 23    {'description': None, 'address1': '701 First A...
# 24    {'description': None, 'address1': '475 Brannan...
# 25    {'description': '', 'address1': '360 Post St. ...
# 26    {'description': '', 'address1': '3525 Eastham ...
# ...                                                 ...
# 8996  {'description': 'Corporate Headquarters', 'add...
# 8997  {'description': '', 'address1': '173 Jefferson...
# 8998  {'description': '', 'address1': '611 Industria...
# 8999  {'description': '', 'address1': '2465-B Faber ...
# 9000  {'description': '', 'address1': '108 boulevard...
# 9001  {'description': 'World Headquarter', 'address1...
# 9002  {'description': 'Toronto Office', 'address1': ...
# 9003  {'description': 'Main Office', 'address1': '80...
# 9004  {'description': 'Main Office', 'address1': '68...
# 9005  {'description': '', 'address1': '', 'address2'...
# 9006  {'description': 'Corporate Headquarters', 'add...
# 9007  {'description': '198 High Holborn', 'address1'...
# 9008  {'description': 'Corporate Office', 'address1'...
# 9009  {'description': '', 'address1': '3700 Haven Co...
# 9010  {'description': '', 'address1': '2635 North 1s...
# 9011  {'description': 'HQ', 'address1': '1350 Willow...
# 9012  {'description': 'Headquarters', 'address1': ''...
# 9012  {'description': 'Menlo Park Office', 'address1...
# 9013  {'description': '', 'address1': '39660 Eureka ...
# 9014  {'description': 'HQ', 'address1': 'Rue des Tan...
# 9015  {'description': '', 'address1': '13280 NW Free...
# 9016  {'description': '', 'address1': '15 Exchange P...
# 9017  {'description': '', 'address1': '11875 Dublin ...
# 9018  {'description': '', 'address1': '2401 East Kat...
# 9019  {'description': '', 'address1': '200 Knickerbo...
# 9020  {'description': '', 'address1': '400 Royal Pal...
# 9021  {'description': '', 'address1': 'LÃ¤rchenweg 7...
# 9022  {'description': 'Livingston', 'address1': 'P.O...
# 9023  {'description': '', 'address1': '', 'address2'...
# 9024  {'description': '', 'address1': '1900 Internat...
#
#                                                     ipo total_money_raised  \
# 0                                                   NaN             $39.8M
# 0                                                   NaN             $39.8M
# 1                                                   NaN                 $0
# 2                                                   NaN                 $0
# 3                                                  None               $45M
# 4     {'valuation_amount': 104000000000, 'valuation_...             $2.43B
# 4     {'valuation_amount': 104000000000, 'valuation_...             $2.43B
# 4     {'valuation_amount': 104000000000, 'valuation_...             $2.43B
# 5                                                  None                 $0
# 6                                                  None             $16.5M
# 7                                                  None                 $0
# 8                                                  None                 $0
# 9     {'valuation_amount': 18100000000, 'valuation_c...             $1.16B
# 10                                                 None             $18.1M
# 11                                                 None             $25.8M
# 12                                                 None             $73.1M
# 13                                                 None             $44.2M
# 14                                                 None                 $0
# 15    {'valuation_amount': None, 'valuation_currency...              $6.7M
# 16                                                 None             $5.58M
# 17                                                 None               $45M
# 18    {'valuation_amount': None, 'valuation_currency...                 $0
# 19    {'valuation_amount': None, 'valuation_currency...                 $0
# 20                                                 None             $13.2M
# 21                                                 None             $28.3M
# 22    {'valuation_amount': None, 'valuation_currency...              $2.5M
# 23    {'valuation_amount': None, 'valuation_currency...              $6.8M
# 24                                                 None             $22.5M
# 25                                                 None             $32.1M
# 26                                                 None               $21M
# ...                                                 ...                ...
# 8996                                               None              $136M
# 8997                                               None              $7.8M
# 8998                                               None                 $0
# 8999                                               None              $6.5M
# 9000                                               None                 $0
# 9001                                               None                 $0
# 9002                                               None                 $0
# 9003                                               None                 $0
# 9004                                               None                 $0
# 9005                                               None                 $0
# 9006                                               None                 $0
# 9007                                               None                 $0
# 9008                                               None              $121M
# 9009                                               None                $2M
# 9010                                               None                $2M
# 9011                                               None             $62.7M
# 9012                                               None                 $0
# 9012                                               None                 $0
# 9013                                               None               $11M
# 9014                                               None             €1.13M
# 9015                                               None                 $0
# 9016                                               None                 $0
# 9017                                               None                 $0
# 9018                                               None                 $0
# 9019                                               None                 $0
# 9020                                               None                 $0
# 9021                                               None                 $0
# 9022                                               None                 $0
# 9023                                               None                 $0
# 9024                                               None                 $0
#
#       deadpooled_year partners
# 0                 1.0       []
# 0                 1.0       []
# 1                 2.0       []
# 2                 3.0       []
# 3                 NaN       []
# 4                 NaN       []
# 4                 NaN       []
# 4                 NaN       []
# 5                 NaN       []
# 6                 NaN       []
# 7                 NaN       []
# 8                 NaN       []
# 9                 NaN       []
# 10                NaN       []
# 11                NaN       []
# 12                NaN       []
# 13                NaN       []
# 14                NaN       []
# 15                NaN       []
# 16                NaN       []
# 17                NaN       []
# 18                NaN       []
# 19                NaN       []
# 20             2013.0       []
# 21                NaN       []
# 22                NaN       []
# 23                NaN       []
# 24                NaN       []
# 25                NaN       []
# 26                NaN       []
# ...               ...      ...
# 8996              NaN       []
# 8997              NaN       []
# 8998              NaN       []
# 8999              NaN       []
# 9000              NaN       []
# 9001              NaN       []
# 9002              NaN       []
# 9003              NaN       []
# 9004              NaN       []
# 9005              NaN       []
# 9006              NaN       []
# 9007              NaN       []
# 9008              NaN       []
# 9009              NaN       []
# 9010              NaN       []
# 9011              NaN       []
# 9012              NaN       []
# 9012              NaN       []
# 9013              NaN       []
# 9014              NaN       []
# 9015              NaN       []
# 9016              NaN       []
# 9017              NaN       []
# 9018              NaN       []
# 9019              NaN       []
# 9020              NaN       []
# 9021              NaN       []
# 9022              NaN       []
# 9023              NaN       []
# 9024              NaN       []
#
# [9708 rows x 8 columns]

# %%
def getOffices(offices):
    offices = df_clean['office']
    principal = None
    for record in offices:
        if record['latitude'] and record['longitude']:
            principal = {
            "type":"Point",
            "coordinates":[record['longitude'], record['latitude']]}
            
        return {
            "lat": record['latitude'],
            "long": record['longitude'],
            "oficina_principal": principal}
            

offices = df_clean[['offices']].apply(getOffices, result_type="expand", axis=1)
offices.head()
# Out:
#          lat        long                                  oficina_principal
# 0  47.603122 -122.333253  {'type': 'Point', 'coordinates': [-122.333253,...
# 0  47.603122 -122.333253  {'type': 'Point', 'coordinates': [-122.333253,...
# 1  47.603122 -122.333253  {'type': 'Point', 'coordinates': [-122.333253,...
# 2  47.603122 -122.333253  {'type': 'Point', 'coordinates': [-122.333253,...
# 3  47.603122 -122.333253  {'type': 'Point', 'coordinates': [-122.333253,...

# %%
#Get API for exchange rate

url = "https://api.exchangeratesapi.io/latest?base=USD"
res = requests.get(url)
rates = res.json()
print(rates)
# Out:
# {'rates': {'CAD': 1.3124497992, 'HKD': 7.8097278001, 'ISK': 126.639892905, 'PHP': 51.3422579206, 'DKK': 6.6607764391, 'HUF': 290.4596162427, 'CZK': 22.7960731816, 'GBP': 0.8029897367, 'RON': 4.218206158, 'SEK': 9.490227577, 'IDR': 14130.0044622936, 'INR': 68.5238732709, 'BRL': 3.8063364569, 'RUB': 63.7221775993, 'HRK': 6.6000892459, 'JPY': 108.817492191, 'THB': 30.8353413655, 'CHF': 0.9939312807, 'EUR': 0.8924587238, 'MYR': 4.1419009371, 'BGN': 1.745470772, 'TRY': 5.6977242303, 'CNY': 6.8857652834, 'NOK': 8.6553324409, 'NZD': 1.5115573405, 'ZAR': 14.1643908969, 'USD': 1.0, 'MXN': 18.9046854083, 'SGD': 1.3609995538, 'AUD': 1.4425702811, 'ILS': 3.5675145025, 'KRW': 1182.55243195, 'PLN': 3.8045515395}, 'base': 'USD', 'date': '2019-07-09'}

# %%
#get currency types


x = []
for i in with_coords2['total_money_raised']:
    y=re.findall("^\D+",i)
    if y not in x:
        x.append(y)
        
print(x)
# Out:
# [['$'], ['€'], ['£'], ['C$'], ['kr']]

# %%
def dropSpaces(currency):
    return currency.rstrip()
    

with_coords2['total_money_raised'] = with_coords2['total_money_raised'].apply(dropSpaces)
# Out:
# /usr/local/Cellar/ipython/7.5.0/libexec/vendor/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
def coinsValues_USD(currency):
    curr_float = float(re.search("\d*\.\d*|\d+", currency)[0])    
    if currency.endswith("M"):
        curr_float= curr_float*1000000
    if currency.endswith("B"):
        curr_float= curr_float*1000000000
    if currency.endswith("k"):
        curr_float= curr_float*1000
    if currency.startswith("€"): 
        curr_float = curr_float*rates['rates']['EUR']
    if currency.startswith("$"): 
        curr_float = curr_float
    if currency.startswith("£"):
        curr_float = curr_float*rates['rates']['GBP']
    if currency.startswith("C$"):
        curr_float = curr_float*rates['rates']['SEK']
    return int(curr_float)

with_coords2['total_USD_raised'] = with_coords2['total_money_raised'].apply(coinsValues_USD)


with_coords2.head(100)
# Out:
# /usr/local/Cellar/ipython/7.5.0/libexec/vendor/lib/python3.7/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                          _id                   name  number_of_employees  \
# 0   52cdef7c4bab8bd675297d8a               Wetpaint                 47.0
# 1   52cdef7c4bab8bd675297d8b              AdventNet                600.0
# 2   52cdef7c4bab8bd675297d8c                   Zoho               1600.0
# 3   52cdef7c4bab8bd675297d8d                   Digg                 60.0
# 4   52cdef7c4bab8bd675297d8e               Facebook               5299.0
# 5   52cdef7c4bab8bd675297d90                Postini                  NaN
# 6   52cdef7c4bab8bd675297d91                   Geni                 18.0
# 7   52cdef7c4bab8bd675297d92                Flektor                  NaN
# 8   52cdef7c4bab8bd675297d93  Fox Interactive Media                  0.0
# 9   52cdef7c4bab8bd675297d94                Twitter               1300.0
# 10  52cdef7c4bab8bd675297d96                 Gizmoz                  NaN
# 11  52cdef7c4bab8bd675297d97                 Scribd                 50.0
# 12  52cdef7c4bab8bd675297d98                Slacker                  NaN
# 13  52cdef7c4bab8bd675297d99                   Lala                  NaN
# 14  52cdef7c4bab8bd675297d9a                  Helio                  NaN
# 15  52cdef7c4bab8bd675297d9b                   eBay              15000.0
# 16  52cdef7c4bab8bd675297d9c                MeetMoi                 15.0
# 17  52cdef7c4bab8bd675297d9d                  Joost                  0.0
# 18  52cdef7c4bab8bd675297d9e                    CBS                  NaN
# 19  52cdef7c4bab8bd675297d9f                 Viacom                  NaN
# 20  52cdef7c4bab8bd675297da0               Babelgum                  NaN
# 21  52cdef7c4bab8bd675297da1                  Plaxo                 50.0
# 22  52cdef7c4bab8bd675297da2                  Cisco              63000.0
# 23  52cdef7c4bab8bd675297da3                 Yahoo!              13600.0
# 24  52cdef7c4bab8bd675297da4               Powerset                 60.0
# 25  52cdef7c4bab8bd675297da5             Technorati                 35.0
# 26  52cdef7c4bab8bd675297da9                 Mahalo                 40.0
# 27  52cdef7c4bab8bd675297daa                Sparter                  NaN
# 28  52cdef7c4bab8bd675297dab                   Kyte                 40.0
# 29  52cdef7c4bab8bd675297dac                   Veoh                  NaN
# ..                       ...                    ...                  ...
# 70  52cdef7c4bab8bd675297dd9                 Steorn                  NaN
# 71  52cdef7c4bab8bd675297ddb                 MeeVee                  NaN
# 72  52cdef7c4bab8bd675297ddc                 blinkx                  NaN
# 73  52cdef7c4bab8bd675297dde             ClipBlast!                 15.0
# 74  52cdef7c4bab8bd675297ddf                   Zlio                  NaN
# 75  52cdef7c4bab8bd675297de0                   Yelp                800.0
# 76  52cdef7c4bab8bd675297de1                  Jaiku                  8.0
# 77  52cdef7c4bab8bd675297de3               Spotplex                  3.0
# 78  52cdef7c4bab8bd675297de5                 TripUp                  NaN
# 79  52cdef7c4bab8bd675297de6                Wakoopa                  8.0
# 80  52cdef7c4bab8bd675297de7                  Fleck                  3.0
# 81  52cdef7c4bab8bd675297de8                Coghead                 21.0
# 82  52cdef7c4bab8bd675297de9                 Zamzar                  2.0
# 83  52cdef7c4bab8bd675297dea                 Zooomr                  NaN
# 84  52cdef7c4bab8bd675297deb               SideStep                 75.0
# 85  52cdef7c4bab8bd675297dec                 coRank                  0.0
# 86  52cdef7c4bab8bd675297ded               Farecast                 26.0
# 87  52cdef7c4bab8bd675297def               KickApps                 72.0
# 88  52cdef7c4bab8bd675297df0                RockYou                106.0
# 89  52cdef7c4bab8bd675297df1              ConVerdge                 25.0
# 90  52cdef7c4bab8bd675297df2             Pageflakes                 20.0
# 91  52cdef7c4bab8bd675297df3          Instructables                  NaN
# 92  52cdef7c4bab8bd675297df5                 Swivel                  1.0
# 93  52cdef7c4bab8bd675297df6                  Slide                 64.0
# 94  52cdef7c4bab8bd675297df7                   Bebo                  0.0
# 95  52cdef7c4bab8bd675297df8                 Flickr                 36.0
# 96  52cdef7c4bab8bd675297df9             BabyCenter                  NaN
# 97  52cdef7c4bab8bd675297dfa           PlaceBlogger                  NaN
# 98  52cdef7c4bab8bd675297dfb                   WeFi                  NaN
# 99  52cdef7c4bab8bd675297dfc                TripHub                  6.0
#
#        category_code                                            offices  \
# 0                web  [{'description': '', 'address1': '710 - 2nd Av...
# 1         enterprise  [{'description': 'Headquarters', 'address1': '...
# 2           software  [{'description': 'Headquarters', 'address1': '...
# 3               news  [{'description': None, 'address1': '135 Missis...
# 4             social  [{'description': 'Headquarters', 'address1': '...
# 5                web  [{'description': None, 'address1': '959 Skyway...
# 6                web  [{'description': 'Headquarters', 'address1': '...
# 7        games_video  [{'description': None, 'address1': '8536 Natio...
# 8                web  [{'description': '', 'address1': '407 N Maple ...
# 9             social  [{'description': '', 'address1': '1355 Market ...
# 10               web  [{'description': None, 'address1': None, 'addr...
# 11              news  [{'description': 'HQ', 'address1': '539 Bryant...
# 12             music  [{'description': '', 'address1': '16935 W. Ber...
# 13       games_video  [{'description': 'Lala Headquarters', 'address...
# 14            mobile  [{'description': None, 'address1': '10960 Wils...
# 15               web  [{'description': 'Headquarters', 'address1': '...
# 16            social  [{'description': None, 'address1': '', 'addres...
# 17       games_video  [{'description': '', 'address1': '100 5th Ave ...
# 18              news  [{'description': None, 'address1': '', 'addres...
# 19               web  [{'description': 'HQ', 'address1': '1515 Broad...
# 20       games_video  [{'description': '', 'address1': '', 'address2...
# 21               web  [{'description': 'HQ', 'address1': '1050 Enter...
# 22   network_hosting  [{'description': 'Headquarters', 'address1': '...
# 23               web  [{'description': None, 'address1': '701 First ...
# 24            search  [{'description': None, 'address1': '475 Branna...
# 25       advertising  [{'description': '', 'address1': '360 Post St....
# 26               web  [{'description': '', 'address1': '3525 Eastham...
# 27       games_video  [{'description': None, 'address1': None, 'addr...
# 28       games_video  [{'description': None, 'address1': '442 Post S...
# 29       games_video  [{'description': '', 'address1': '10180 Telesi...
# ..               ...                                                ...
# 70               web  [{'description': None, 'address1': 'East Wall ...
# 71       games_video  [{'description': None, 'address1': '500 Airpor...
# 72       games_video  [{'description': None, 'address1': '1 Market S...
# 73               web  [{'description': None, 'address1': '5737 Kanan...
# 74         ecommerce  [{'description': '', 'address1': '55 rue Serva...
# 75            search  [{'description': '', 'address1': '706 Mission ...
# 76            mobile  [{'description': None, 'address1': 'Lannrotink...
# 77               web  [{'description': None, 'address1': '3160 De La...
# 78               web  [{'description': None, 'address1': None, 'addr...
# 79               web  [{'description': 'Arts & Crafts', 'address1': ...
# 80               web  [{'description': None, 'address1': 'Oosterdoks...
# 81               web  [{'description': None, 'address1': None, 'addr...
# 82               web  [{'description': '', 'address1': '', 'address2...
# 83               web  [{'description': None, 'address1': None, 'addr...
# 84               web  [{'description': None, 'address1': '2980 Bower...
# 85               web  [{'description': None, 'address1': None, 'addr...
# 86            search  [{'description': None, 'address1': '200 West T...
# 87        enterprise  [{'description': 'Headquarters', 'address1': '...
# 88       games_video  [{'description': '', 'address1': '585 Broadway...
# 89        enterprise  [{'description': '', 'address1': '', 'address2...
# 90               web  [{'description': None, 'address1': '795 Folsom...
# 91               web  [{'description': '', 'address1': '489 Clementi...
# 92            search  [{'description': None, 'address1': '199 Fremon...
# 93  public_relations  [{'description': '', 'address1': '301 Brannan ...
# 94               web  [{'description': '', 'address1': '425 Bush Str...
# 95               web  [{'description': 'HQ', 'address1': '701 1st av...
# 96               web  [{'description': '', 'address1': '163 Freelon ...
# 97               web  [{'description': None, 'address1': '', 'addres...
# 98            mobile  [{'description': None, 'address1': '12587 Fair...
# 99               web  [{'description': None, 'address1': '2033 6th A...
#
#     founded_year                                                ipo  \
# 0         2005.0                                                NaN
# 1         1996.0                                                NaN
# 2         2005.0                                                NaN
# 3         2004.0                                               None
# 4         2004.0  {'valuation_amount': 104000000000, 'valuation_...
# 5         1999.0                                               None
# 6         2006.0                                               None
# 7            NaN                                               None
# 8         1979.0                                               None
# 9         2006.0  {'valuation_amount': 18100000000, 'valuation_c...
# 10        2003.0                                               None
# 11        2007.0                                               None
# 12        2006.0                                               None
# 13           NaN                                               None
# 14        2005.0                                               None
# 15        1995.0  {'valuation_amount': None, 'valuation_currency...
# 16        2007.0                                               None
# 17        2006.0                                               None
# 18        1986.0  {'valuation_amount': None, 'valuation_currency...
# 19        1971.0  {'valuation_amount': None, 'valuation_currency...
# 20        2007.0                                               None
# 21        2002.0                                               None
# 22        1984.0  {'valuation_amount': None, 'valuation_currency...
# 23        1994.0  {'valuation_amount': None, 'valuation_currency...
# 24        2006.0                                               None
# 25        2002.0                                               None
# 26        2007.0                                               None
# 27        2007.0                                               None
# 28        2006.0                                               None
# 29        2004.0                                               None
# ..           ...                                                ...
# 70        2000.0                                               None
# 71        2000.0                                               None
# 72        2004.0  {'valuation_amount': None, 'valuation_currency...
# 73        2005.0                                               None
# 74        2005.0                                               None
# 75        2004.0  {'valuation_amount': 1300000000, 'valuation_cu...
# 76        2006.0                                               None
# 77        2007.0                                               None
# 78        2006.0                                               None
# 79        2007.0                                               None
# 80        2006.0                                               None
# 81        2003.0                                               None
# 82        2006.0                                               None
# 83        2006.0                                               None
# 84        1999.0                                               None
# 85        2007.0                                               None
# 86        2003.0                                               None
# 87        2004.0                                               None
# 88        2005.0                                               None
# 89        2006.0                                               None
# 90        2006.0                                               None
# 91        2005.0                                               None
# 92        2005.0                                               None
# 93        2005.0                                               None
# 94        2005.0                                               None
# 95        2004.0                                               None
# 96        1997.0                                               None
# 97           NaN                                               None
# 98        2006.0                                               None
# 99        2005.0                                               None
#
#                                        funding_rounds total_money_raised  \
# 0   [{'id': 888, 'round_code': 'a', 'source_url': ...             $39.8M
# 1                                                  []                 $0
# 2                                                  []                 $0
# 3   [{'id': 1, 'round_code': 'b', 'source_url': 'h...               $45M
# 4   [{'id': 2, 'round_code': 'angel', 'source_url'...             $2.43B
# 5                                                  []                 $0
# 6   [{'id': 6, 'round_code': 'a', 'source_url': ''...             $16.5M
# 7                                                  []                 $0
# 8                                                  []                 $0
# 9   [{'id': 261, 'round_code': 'a', 'source_url': ...             $1.16B
# 10  [{'id': 9, 'round_code': 'a', 'source_url': 'h...             $18.1M
# 11  [{'id': 10, 'round_code': 'seed', 'source_url'...             $25.8M
# 12  [{'id': 12, 'round_code': 'b', 'source_url': '...             $73.1M
# 13  [{'id': 16, 'round_code': 'b', 'source_url': '...             $44.2M
# 14                                                 []                 $0
# 15  [{'id': 24534, 'round_code': 'unattributed', '...              $6.7M
# 16  [{'id': 18, 'round_code': 'a', 'source_url': '...             $5.58M
# 17  [{'id': 19, 'round_code': 'a', 'source_url': '...               $45M
# 18                                                 []                 $0
# 19                                                 []                 $0
# 20  [{'id': 17, 'round_code': 'a', 'source_url': '...             $13.2M
# 21  [{'id': 20, 'round_code': 'a', 'source_url': '...             $28.3M
# 22  [{'id': 2232, 'round_code': 'a', 'source_url':...              $2.5M
# 23  [{'id': 24531, 'round_code': 'a', 'source_url'...              $6.8M
# 24  [{'id': 22, 'round_code': 'a', 'source_url': '...             $22.5M
# 25  [{'id': 23, 'round_code': 'c', 'source_url': '...             $32.1M
# 26  [{'id': 323, 'round_code': 'a', 'source_url': ...               $21M
# 27                                                 []                 $0
# 28  [{'id': 32, 'round_code': 'a', 'source_url': '...             $23.4M
# 29  [{'id': 33, 'round_code': 'b', 'source_url': '...             $69.8M
# ..                                                ...                ...
# 70                                                 []                 $0
# 71  [{'id': 90, 'round_code': 'b', 'source_url': '...               $25M
# 72                                                 []                 $0
# 73                                                 []                 $0
# 74  [{'id': 94, 'round_code': 'a', 'source_url': '...                $4M
# 75  [{'id': 95, 'round_code': 'c', 'source_url': '...               $90M
# 76                                                 []                 $0
# 77  [{'id': 108, 'round_code': 'angel', 'source_ur...              $450k
# 78                                                 []                 $0
# 79  [{'id': 100, 'round_code': 'a', 'source_url': ...                $1M
# 80  [{'id': 101, 'round_code': 'angel', 'source_ur...              €225k
# 81  [{'id': 102, 'round_code': 'a', 'source_url': ...             $11.2M
# 82                                                 []                 $0
# 83  [{'id': 106, 'round_code': 'angel', 'source_ur...               $50k
# 84  [{'id': 105, 'round_code': 'c', 'source_url': ...               $32M
# 85  [{'id': 104, 'round_code': 'seed', 'source_url...                 $0
# 86  [{'id': 109, 'round_code': 'a', 'source_url': ...             $20.6M
# 87  [{'id': 347, 'round_code': 'b', 'source_url': ...               $32M
# 88  [{'id': 115, 'round_code': 'a', 'source_url': ...              $136M
# 89                                                 []                 $0
# 90  [{'id': 117, 'round_code': 'a', 'source_url': ...              $4.1M
# 91                                                 []                 $0
# 92  [{'id': 125, 'round_code': 'a', 'source_url': ...                $2M
# 93  [{'id': 122, 'round_code': 'c', 'source_url': ...               $78M
# 94  [{'id': 121, 'round_code': 'a', 'source_url': ...               $15M
# 95  [{'id': 7024, 'round_code': 'unattributed', 's...                 $0
# 96                                                 []                 $0
# 97  [{'id': 546, 'round_code': 'seed', 'source_url...                $5M
# 98  [{'id': 547, 'round_code': 'a', 'source_url': ...               $10M
# 99                                                 []                 $0
#
#                                           investments  deadpooled_year  \
# 0                                                  []              1.0
# 1                                                  []              2.0
# 2                                                  []              3.0
# 3                                                  []              NaN
# 4   [{'funding_round': {'round_code': 'seed', 'sou...              NaN
# 5                                                  []              NaN
# 6                                                  []              NaN
# 7                                                  []              NaN
# 8   [{'funding_round': {'round_code': 'b', 'source...              NaN
# 9                                                  []              NaN
# 10                                                 []              NaN
# 11                                                 []              NaN
# 12                                                 []              NaN
# 13                                                 []              NaN
# 14                                                 []              NaN
# 15  [{'funding_round': {'round_code': 'c', 'source...              NaN
# 16                                                 []              NaN
# 17                                                 []              NaN
# 18  [{'funding_round': {'round_code': 'b', 'source...              NaN
# 19  [{'funding_round': {'round_code': 'b', 'source...              NaN
# 20                                                 []           2013.0
# 21                                                 []              NaN
# 22  [{'funding_round': {'round_code': 'c', 'source...              NaN
# 23  [{'funding_round': {'round_code': 'c', 'source...              NaN
# 24                                                 []              NaN
# 25                                                 []              NaN
# 26                                                 []              NaN
# 27                                                 []           2008.0
# 28                                                 []              NaN
# 29                                                 []              NaN
# ..                                                ...              ...
# 70                                                 []              NaN
# 71                                                 []              NaN
# 72                                                 []              NaN
# 73                                                 []              NaN
# 74                                                 []           2011.0
# 75                                                 []              NaN
# 76                                                 []           2012.0
# 77                                                 []           2008.0
# 78                                                 []           2008.0
# 79                                                 []              NaN
# 80                                                 []           2008.0
# 81                                                 []           2009.0
# 82                                                 []              NaN
# 83                                                 []           2006.0
# 84                                                 []              NaN
# 85                                                 []              NaN
# 86                                                 []              NaN
# 87                                                 []              NaN
# 88                                                 []              NaN
# 89                                                 []              NaN
# 90                                                 []              NaN
# 91                                                 []              NaN
# 92                                                 []           2010.0
# 93                                                 []           2011.0
# 94                                                 []              NaN
# 95                                                 []              NaN
# 96                                                 []              NaN
# 97                                                 []           2012.0
# 98                                                 []              NaN
# 99                                                 []           2008.0
#
#    partners  total_USD_raised
# 0        []          39800000
# 1        []                 0
# 2        []                 0
# 3        []          45000000
# 4        []        2430000000
# 5        []                 0
# 6        []          16500000
# 7        []                 0
# 8        []                 0
# 9        []        1160000000
# 10       []          18100000
# 11       []          25800000
# 12       []          73100000
# 13       []          44200000
# 14       []                 0
# 15       []           6700000
# 16       []           5580000
# 17       []          45000000
# 18       []                 0
# 19       []                 0
# 20       []          13200000
# 21       []          28300000
# 22       []           2500000
# 23       []           6800000
# 24       []          22500000
# 25       []          32100000
# 26       []          21000000
# 27       []                 0
# 28       []          23400000
# 29       []          69800000
# ..      ...               ...
# 70       []                 0
# 71       []          25000000
# 72       []                 0
# 73       []                 0
# 74       []           4000000
# 75       []          90000000
# 76       []                 0
# 77       []            450000
# 78       []                 0
# 79       []           1000000
# 80       []            200803
# 81       []          11200000
# 82       []                 0
# 83       []             50000
# 84       []          32000000
# 85       []                 0
# 86       []          20600000
# 87       []          32000000
# 88       []         136000000
# 89       []                 0
# 90       []           4099999
# 91       []                 0
# 92       []           2000000
# 93       []          78000000
# 94       []          15000000
# 95       []                 0
# 96       []                 0
# 97       []           5000000
# 98       []          10000000
# 99       []                 0
#
# [100 rows x 13 columns]

# %%
with_coords2[['name','offices','number_of_employees','category_code','founded_year','ipo','total_USD_raised','deadpooled_year']]
with_coords.shape
# Out:
# (9025, 42)

# %%
#GetOffices
# Out:
# 0       [{'description': '', 'address1': '710 - 2nd Av...
# 1       [{'description': 'Headquarters', 'address1': '...
# 2       [{'description': 'Headquarters', 'address1': '...
# 3       [{'description': None, 'address1': '135 Missis...
# 4       [{'description': 'Headquarters', 'address1': '...
# 5       [{'description': None, 'address1': '959 Skyway...
# 6       [{'description': 'Headquarters', 'address1': '...
# 7       [{'description': None, 'address1': '8536 Natio...
# 8       [{'description': '', 'address1': '407 N Maple ...
# 9       [{'description': '', 'address1': '1355 Market ...
# 10      [{'description': None, 'address1': None, 'addr...
# 11      [{'description': 'HQ', 'address1': '539 Bryant...
# 12      [{'description': '', 'address1': '16935 W. Ber...
# 13      [{'description': 'Lala Headquarters', 'address...
# 14      [{'description': None, 'address1': '10960 Wils...
# 15      [{'description': 'Headquarters', 'address1': '...
# 16      [{'description': None, 'address1': '', 'addres...
# 17      [{'description': '', 'address1': '100 5th Ave ...
# 18      [{'description': None, 'address1': '', 'addres...
# 19      [{'description': 'HQ', 'address1': '1515 Broad...
# 20      [{'description': '', 'address1': '', 'address2...
# 21      [{'description': 'HQ', 'address1': '1050 Enter...
# 22      [{'description': 'Headquarters', 'address1': '...
# 23      [{'description': None, 'address1': '701 First ...
# 24      [{'description': None, 'address1': '475 Branna...
# 25      [{'description': '', 'address1': '360 Post St....
# 26      [{'description': '', 'address1': '3525 Eastham...
# 27      [{'description': None, 'address1': None, 'addr...
# 28      [{'description': None, 'address1': '442 Post S...
# 29      [{'description': '', 'address1': '10180 Telesi...
#                               ...
# 8995    [{'description': 'ITERNOVA TERUEL', 'address1'...
# 8996    [{'description': 'Corporate Headquarters', 'ad...
# 8997    [{'description': '', 'address1': '173 Jefferso...
# 8998    [{'description': '', 'address1': '611 Industri...
# 8999    [{'description': '', 'address1': '2465-B Faber...
# 9000    [{'description': '', 'address1': '108 boulevar...
# 9001    [{'description': 'World Headquarter', 'address...
# 9002    [{'description': 'Toronto Office', 'address1':...
# 9003    [{'description': 'Main Office', 'address1': '8...
# 9004    [{'description': 'Main Office', 'address1': '6...
# 9005    [{'description': '', 'address1': '', 'address2...
# 9006    [{'description': 'Corporate Headquarters', 'ad...
# 9007    [{'description': '198 High Holborn', 'address1...
# 9008    [{'description': 'Corporate Office', 'address1...
# 9009    [{'description': '', 'address1': '3700 Haven C...
# 9010    [{'description': '', 'address1': '2635 North 1...
# 9011    [{'description': 'HQ', 'address1': '1350 Willo...
# 9012    [{'description': 'Headquarters', 'address1': '...
# 9013    [{'description': '', 'address1': '39660 Eureka...
# 9014    [{'description': 'HQ', 'address1': 'Rue des Ta...
# 9015    [{'description': '', 'address1': '13280 NW Fre...
# 9016    [{'description': '', 'address1': '15 Exchange ...
# 9017    [{'description': '', 'address1': '11875 Dublin...
# 9018    [{'description': '', 'address1': '2401 East Ka...
# 9019    [{'description': '', 'address1': '200 Knickerb...
# 9020    [{'description': '', 'address1': '400 Royal Pa...
# 9021    [{'description': '', 'address1': 'LÃ¤rchenweg ...
# 9022    [{'description': 'Livingston', 'address1': 'P....
# 9023    [{'description': '', 'address1': '', 'address2...
# 9024    [{'description': '', 'address1': '1900 Interna...
# Name: offices, Length: 9025, dtype: object
