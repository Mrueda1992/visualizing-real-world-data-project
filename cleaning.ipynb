# %%
from pymongo import MongoClient
import pandas as pd
import re
import requests
import json


client = MongoClient('mongodb://localhost:27017/')
db = client.company

# %%
#query to filter database by deadpooled year, employees, founded year, lat and long. 

query= db.company.find({
    "$and":
    [{"deadpooled_year":None},
     {"number_of_employees":{"$ne":None}},
     {"founded_year":{"$gte":2007}},
     {"offices.longitude":{"$exists":True}},
     {"offices.latitude":{"$ne":None}},
     {"offices.longitude":{"$ne":None}},
     {"offices.longitude":{"$exists":True}
     }
    ]
}
)

# %%
print(query)
# Out:
# <pymongo.cursor.Cursor object at 0x14bac3828>

# %%
with_coords = pd.DataFrame(query)
with_coords.shape
# Out:
# (2152, 42)

# %%
#New DF with filtered columns
with_coords2 = with_coords[['_id','name','number_of_employees','category_code','offices','founded_year','ipo','funding_rounds','total_money_raised','investments','deadpooled_year','partners']]
with_coords2.head(100)
with_coords2.shape
# Out:
# (2152, 12)

# %%
#Get Offices

get_offices= pd.DataFrame(with_coords2['offices'].tolist()).stack().reset_index(level=1, drop=True)
office = get_offices.rename('office')
office.shape
# Out:
# (2292,)

# %%
#merge dataframe with new columns

df_clean= with_coords2.merge(office, left_index= True, right_index=True)

df_clean = df_clean[['name','number_of_employees','category_code','office','ipo','total_money_raised','founded_year','deadpooled_year','offices']]
df_clean.head(100)
print(df_clean[['office']])
# Out:
#                                                  office
# 0     {'description': 'HQ', 'address1': '539 Bryant ...
# 1     {'description': None, 'address1': '', 'address...
# 2     {'description': '', 'address1': '3525 Eastham ...
# 3     {'description': 'Livestream HQ', 'address1': '...
# 4     {'description': '', 'address1': '131 Varick St...
# 5     {'description': '', 'address1': '1459 18th Str...
# 6     {'description': None, 'address1': None, 'addre...
# 7     {'description': '', 'address1': '16161 Ventura...
# 8     {'description': 'Arts & Crafts', 'address1': '...
# 9     {'description': None, 'address1': None, 'addre...
# 10    {'description': '', 'address1': '53 S Knoll Rd...
# 11    {'description': '', 'address1': '1550 Bryant S...
# 12    {'description': None, 'address1': None, 'addre...
# 13    {'description': 'GoingOn Networks, Inc.', 'add...
# 14    {'description': '', 'address1': '', 'address2'...
# 15    {'description': '', 'address1': '', 'address2'...
# 16    {'description': 'boo-land', 'address1': 'Av. F...
# 17    {'description': '', 'address1': '181 Fremont S...
# 18    {'description': 'headquarter', 'address1': '17...
# 19    {'description': '', 'address1': '300 S Ellswor...
# 20    {'description': 'HQ', 'address1': '1050 Walnut...
# 21    {'description': 'HQ', 'address1': '325 Lytton ...
# 22    {'description': '', 'address1': '129 South Str...
# 23    {'description': '', 'address1': '329 Bryant St...
# 24    {'description': '', 'address1': '409 S Santa M...
# 25    {'description': '', 'address1': '8 Clifford St...
# 26    {'description': 'HQ', 'address1': 'One Broadwa...
# 27    {'description': None, 'address1': None, 'addre...
# 28    {'description': '', 'address1': '', 'address2'...
# 29    {'description': '', 'address1': '315 5th Ave S...
# ...                                                 ...
# 2124  {'description': 'Tiverias Apps LLC.', 'address...
# 2125  {'description': 'New York', 'address1': 'PO Bo...
# 2126  {'description': 'Mailing Address', 'address1':...
# 2127  {'description': 'Headquarters', 'address1': '7...
# 2128  {'description': 'HOTForms123', 'address1': '46...
# 2129  {'description': 'HQ', 'address1': '150 Munson ...
# 2130  {'description': 'Vancouver Office', 'address1'...
# 2131  {'description': 'Los Angeles', 'address1': '10...
# 2132  {'description': 'Oxford Office', 'address1': '...
# 2133  {'description': 'Base', 'address1': '', 'addre...
# 2134  {'description': '', 'address1': '11 Lupine Ave...
# 2135  {'description': 'Miami Office', 'address1': '2...
# 2136  {'description': 'Head Office', 'address1': '96...
# 2137  {'description': 'Headquarters', 'address1': 'S...
# 2138  {'description': '', 'address1': '143 Varick St...
# 2139  {'description': 'Primary Office', 'address1': ...
# 2140  {'description': 'New York', 'address1': '32-14...
# 2140  {'description': 'Houston', 'address1': '2208 C...
# 2141  {'description': 'HQ', 'address1': '', 'address...
# 2142  {'description': 'Jelli, Inc.', 'address1': '4 ...
# 2143  {'description': '', 'address1': '163 Hastings ...
# 2144  {'description': 'Lisbon Office', 'address1': '...
# 2145  {'description': '', 'address1': '108 boulevard...
# 2146  {'description': 'Toronto Office', 'address1': ...
# 2147  {'description': 'Main Office', 'address1': '68...
# 2148  {'description': '', 'address1': '', 'address2'...
# 2149  {'description': '198 High Holborn', 'address1'...
# 2150  {'description': 'Headquarters', 'address1': ''...
# 2150  {'description': 'Menlo Park Office', 'address1...
# 2151  {'description': 'HQ', 'address1': 'Rue des Tan...
#
# [2292 rows x 1 columns]

# %%
#get latitude, longitude and office ID

def getOffices(offices):
    offices = offices['office']
    principal = None
    if offices['latitude'] and offices ['longitude']:
        
        principal = {
            "type":"Point",
            "coordinates":[offices['longitude'], offices['latitude']]
        }

        return {
            "long": offices['longitude'],
            "lat": offices['latitude'],
            "oficina": principal
        }
            

offices = df_clean[['office']].apply(getOffices, result_type="expand", axis=1)
offices.head(100)
# Out:
#           lat        long                                            oficina
# 0   37.789634 -122.404052  {'type': 'Point', 'coordinates': [-122.404052,...
# 1   40.757929  -73.985506  {'type': 'Point', 'coordinates': [-73.985506, ...
# 2   34.017606 -118.487267  {'type': 'Point', 'coordinates': [-118.487267,...
# 3   40.726155  -73.995625  {'type': 'Point', 'coordinates': [-73.995625, ...
# 4   40.801358  -74.337200  {'type': 'Point', 'coordinates': [-74.3372, 40...
# 5   37.762541 -122.397224  {'type': 'Point', 'coordinates': [-122.397224,...
# 6   37.269175 -119.306607  {'type': 'Point', 'coordinates': [-119.306607,...
# 7   37.269175 -119.306607  {'type': 'Point', 'coordinates': [-119.306607,...
# 8   52.374523    4.894862  {'type': 'Point', 'coordinates': [4.8948623, 5...
# 9   37.369650 -122.024210  {'type': 'Point', 'coordinates': [-122.02421, ...
# 10  37.900770 -122.511687  {'type': 'Point', 'coordinates': [-122.511687,...
# 86  37.798853 -122.398599  {'type': 'Point', 'coordinates': [-122.398599,...
# 87  40.521502  -74.275771  {'type': 'Point', 'coordinates': [-74.275771, ...
# 87  32.718834 -117.163841  {'type': 'Point', 'coordinates': [-117.163841,...
# 88  49.225902   16.569282  {'type': 'Point', 'coordinates': [16.5692822, ...
# 89  37.090240  -95.712891  {'type': 'Point', 'coordinates': [-95.712891, ...
# 90  51.522413   -0.092690  {'type': 'Point', 'coordinates': [-0.0926903, ...
# 91  37.090240  -95.712891  {'type': 'Point', 'coordinates': [-95.712891, ...
# 92  39.851338 -105.139804  {'type': 'Point', 'coordinates': [-105.139804,...
# 93  37.789129 -122.402028  {'type': 'Point', 'coordinates': [-122.4020276...
# 94  34.031764 -118.461884  {'type': 'Point', 'coordinates': [-118.461884,...
# 95  37.290603 -121.931785  {'type': 'Point', 'coordinates': [-121.9317853...
# 96  37.775196 -122.419204  {'type': 'Point', 'coordinates': [-122.419204,...
# 97  37.788266 -122.403865  {'type': 'Point', 'coordinates': [-122.403865,...
#
# [100 rows x 3 columns]

# %%
#Concatenar dos dataframes

df_concat = pd.concat([df_clean,offices], axis=1)
df_concat.head()
# Out:
#            name  number_of_employees category_code  \
# 0        Scribd                   50          news
# 1       MeetMoi                   15        social
# 2        Mahalo                   40           web
# 3    Livestream                  120   games_video
# 4  AdaptiveBlue                   15   games_video
#
#                                               office   ipo total_money_raised  \
# 0  {'description': 'HQ', 'address1': '539 Bryant ...  None             $25.8M
# 1  {'description': None, 'address1': '', 'address...  None             $5.58M
# 2  {'description': '', 'address1': '3525 Eastham ...  None               $21M
# 3  {'description': 'Livestream HQ', 'address1': '...  None             $14.7M
# 4  {'description': '', 'address1': '131 Varick St...  None               $24M
#
#    founded_year deadpooled_year  \
# 0          2007            None
# 1          2007            None
# 2          2007            None
# 3          2007            None
# 4          2007            None
#
#                                              offices        lat        long  \
# 0  [{'description': 'HQ', 'address1': '539 Bryant...  37.789634 -122.404052
# 1  [{'description': None, 'address1': '', 'addres...  40.757929  -73.985506
# 2  [{'description': '', 'address1': '3525 Eastham...  34.017606 -118.487267
# 3  [{'description': 'Livestream HQ', 'address1': ...  40.726155  -73.995625
# 4  [{'description': '', 'address1': '131 Varick S...  40.801358  -74.337200
#
#                                              oficina
# 0  {'type': 'Point', 'coordinates': [-122.404052,...
# 1  {'type': 'Point', 'coordinates': [-73.985506, ...
# 2  {'type': 'Point', 'coordinates': [-118.487267,...
# 3  {'type': 'Point', 'coordinates': [-73.995625, ...
# 4  {'type': 'Point', 'coordinates': [-74.3372, 40...

# %%
#Get API for exchange rate

url = "https://api.exchangeratesapi.io/latest?base=USD"
res = requests.get(url)
rates = res.json()
print(rates)
# Out:
# {'rates': {'CAD': 1.3113190731, 'HKD': 7.8156862745, 'ISK': 126.4705882353, 'PHP': 51.4759358289, 'DKK': 6.6521390374, 'HUF': 290.4634581105, 'CZK': 22.7852049911, 'GBP': 0.8014973262, 'RON': 4.2188057041, 'SEK': 9.4557040998, 'IDR': 14130.0, 'INR': 68.5837789661, 'BRL': 3.7954545455, 'RUB': 63.5200534759, 'HRK': 6.5895721925, 'JPY': 108.9126559715, 'THB': 30.825311943, 'CHF': 0.9922459893, 'EUR': 0.8912655971, 'MYR': 4.1385026738, 'BGN': 1.7431372549, 'TRY': 5.7395721925, 'CNY': 6.8829768271, 'NOK': 8.6390374332, 'NZD': 1.5148841355, 'ZAR': 14.1599821747, 'USD': 1.0, 'MXN': 19.1997326203, 'SGD': 1.3609625668, 'AUD': 1.444741533, 'ILS': 3.5721925134, 'KRW': 1181.1140819964, 'PLN': 3.8090909091}, 'base': 'USD', 'date': '2019-07-10'}

# %%
#get currency types


x = []
for i in df_concat['total_money_raised']:
    y=re.findall("^\D+",i)
    if y not in x:
        x.append(y)
        
print(x)
# Out:
# [['$'], ['€'], ['£'], ['C$']]

# %%
def dropSpaces(currency):
    return currency.rstrip()
    

with_coords2['total_money_raised'] = with_coords2['total_money_raised'].apply(dropSpaces)
# Out:
# /usr/local/Cellar/ipython/7.5.0/libexec/vendor/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
def coinsValues_USD(currency):
    curr_float = float(re.search("\d*\.\d*|\d+", currency)[0])    
    if currency.endswith("M"):
        curr_float= curr_float*1000000
    if currency.endswith("B"):
        curr_float= curr_float*1000000000
    if currency.endswith("k"):
        curr_float= curr_float*1000
    if currency.startswith("€"): 
        curr_float = curr_float*rates['rates']['EUR']
    if currency.startswith("$"): 
        curr_float = curr_float
    if currency.startswith("£"):
        curr_float = curr_float*rates['rates']['GBP']
    if currency.startswith("C$"):
        curr_float = curr_float*rates['rates']['SEK']
    return int(curr_float)

df_concat['total_USD_raised'] = df_concat['total_money_raised'].apply(coinsValues_USD)


df_concat.head(100)
# Out:
#                name  number_of_employees    category_code  \
# 0            Scribd                   50             news
# 1           MeetMoi                   15           social
# 2            Mahalo                   40              web
# 3        Livestream                  120      games_video
# 4      AdaptiveBlue                   15      games_video
# 5            Pownce                    6              web
# 6   CriticalMetrics                    4              web
# 7          SodaHead                   25              web
# 8           Wakoopa                    8              web
# 9            coRank                    0              web
# 10        CrowdVine                   10              web
# 11          Seesmic                   13              web
# 12         Cofoundr                    0  network_hosting
# 13          GoingOn                   40         software
# 14           FeVote                    1              web
# 15           Buxfer                    4              web
# 16          boo-box                   50      advertising
# 17           Scrybe                   20       enterprise
# 18             Echo                   50       enterprise
# 19      Inneractive                    0      advertising
# 20      Socialthing                    5  network_hosting
# 21         Filtrbox                   14              web
# 22         Cloudant                   70       enterprise
# 23           Zivity                   16  network_hosting
# 24          Docstoc                   40              web
# 25         Seedcamp                    4          finance
# 26         LocaModa                    0      advertising
# 27          YouBeQB                    8      games_video
# 28       MicroPlace                   15              web
# 29           EyeJot                    5              web
# ..              ...                  ...              ...
# 70       divorce360                    6              web
# 71        eventsbot                   10              web
# 72         Uversity                   30           social
# 72         Uversity                   30           social
# 73            eBurl                    1              web
# 74           GoLark                    3              web
# 75        Flixwagon                   10           mobile
# 76       Picktastic                    2      games_video
# 77        CareFlash                    0              web
# 78           Acquia                  400       enterprise
# 79         LiveHire                    5      games_video
# 80       TravelMuse                   11              web
# 81           Driftr                    0              web
# 82           Orglex                    0              web
# 83            Mogad                    2  network_hosting
# 84        Livemocha                   35        education
# 85            Mpayy                    2        ecommerce
# 86        Widgetbox                   30            other
# 87     CheerOutLoud                    0              web
# 87     CheerOutLoud                    0              web
# 88          Webnode                   30  network_hosting
# 89           Frevvo                   10              web
# 90       UnLtdWorld                    4       enterprise
# 91           Boobik                    3              web
# 92        Blogonize                    1              web
# 93            Roost                   15         software
# 94      WonderHowTo                   12      games_video
# 95         clipsync                   28              web
# 96           Heroku                   80       enterprise
# 97          Lookery                    9              web
#
#                                                office   ipo  \
# 0   {'description': 'HQ', 'address1': '539 Bryant ...  None
# 1   {'description': None, 'address1': '', 'address...  None
# 2   {'description': '', 'address1': '3525 Eastham ...  None
# 3   {'description': 'Livestream HQ', 'address1': '...  None
# 4   {'description': '', 'address1': '131 Varick St...  None
# 5   {'description': '', 'address1': '1459 18th Str...  None
# 6   {'description': None, 'address1': None, 'addre...  None
# 7   {'description': '', 'address1': '16161 Ventura...  None
# 8   {'description': 'Arts & Crafts', 'address1': '...  None
# 9   {'description': None, 'address1': None, 'addre...  None
# 10  {'description': '', 'address1': '53 S Knoll Rd...  None
# 11  {'description': '', 'address1': '1550 Bryant S...  None
# 12  {'description': None, 'address1': None, 'addre...  None
# 13  {'description': 'GoingOn Networks, Inc.', 'add...  None
# 14  {'description': '', 'address1': '', 'address2'...  None
# 15  {'description': '', 'address1': '', 'address2'...  None
# 16  {'description': 'boo-land', 'address1': 'Av. F...  None
# 17  {'description': '', 'address1': '181 Fremont S...  None
# 18  {'description': 'headquarter', 'address1': '17...  None
# 19  {'description': '', 'address1': '300 S Ellswor...  None
# 20  {'description': 'HQ', 'address1': '1050 Walnut...  None
# 21  {'description': 'HQ', 'address1': '325 Lytton ...  None
# 22  {'description': '', 'address1': '129 South Str...  None
# 23  {'description': '', 'address1': '329 Bryant St...  None
# 24  {'description': '', 'address1': '409 S Santa M...  None
# 25  {'description': '', 'address1': '8 Clifford St...  None
# 26  {'description': 'HQ', 'address1': 'One Broadwa...  None
# 27  {'description': None, 'address1': None, 'addre...  None
# 28  {'description': '', 'address1': '', 'address2'...  None
# 29  {'description': '', 'address1': '315 5th Ave S...  None
# ..                                                ...   ...
# 70  {'description': None, 'address1': '760 US High...  None
# 71  {'description': None, 'address1': '571 Bucking...  None
# 72  {'description': None, 'address1': None, 'addre...  None
# 72  {'description': None, 'address1': None, 'addre...  None
# 73  {'description': None, 'address1': '', 'address...  None
# 74  {'description': None, 'address1': '', 'address...  None
# 75  {'description': None, 'address1': None, 'addre...  None
# 76  {'description': None, 'address1': None, 'addre...  None
# 77  {'description': 'CareFlash LLC', 'address1': '...  None
# 78  {'description': 'HQ', 'address1': '25 Corporat...  None
# 79  {'description': None, 'address1': '510 Thornal...  None
# 80  {'description': '', 'address1': '55 Broad Stre...  None
# 81  {'description': None, 'address1': '', 'address...  None
# 82  {'description': None, 'address1': None, 'addre...  None
# 83  {'description': None, 'address1': '579 Valenci...  None
# 84  {'description': '', 'address1': '1011 Western ...  None
# 85  {'description': None, 'address1': '101 N Wacke...  None
# 86  {'description': None, 'address1': None, 'addre...  None
# 87  {'description': '', 'address1': '', 'address2'...  None
# 87  {'description': '', 'address1': '', 'address2'...  None
# 88  {'description': '', 'address1': 'U vodarny 2',...  None
# 89  {'description': None, 'address1': None, 'addre...  None
# 90  {'description': '', 'address1': '123 Whitecros...  None
# 91  {'description': '', 'address1': '', 'address2'...  None
# 92  {'description': None, 'address1': '12459 W 84t...  None
# 93  {'description': '', 'address1': '50 Beale St. ...  None
# 94  {'description': None, 'address1': '1832 Frankl...  None
# 95  {'description': '', 'address1': 'Pier 33 South...  None
# 96  {'description': None, 'address1': '', 'address...  None
# 97  {'description': 'West Coast', 'address1': '25 ...  None
#
#    total_money_raised  founded_year deadpooled_year  \
# 0              $25.8M          2007            None
# 1              $5.58M          2007            None
# 2                $21M          2007            None
# 3              $14.7M          2007            None
# 4                $24M          2007            None
# 5                  $0          2007            None
# 6               $100k          2007            None
# 7              $12.7M          2007            None
# 8                 $1M          2007            None
# 9                  $0          2007            None
# 10                 $0          2007            None
# 11               $16M          2007            None
# 12                 $0          2007            None
# 13              $8.5M          2008            None
# 14                 $0          2007            None
# 15              $315k          2007            None
# 16              $300k          2007            None
# 17             $1.31M          2007            None
# 18              $4.8M          2007            None
# 19              $8.5M          2007            None
# 20              $415k          2007            None
# 21             $1.92M          2007            None
# 22             $18.3M          2008            None
# 23                $8M          2007            None
# 24                $4M          2007            None
# 25                €5M          2007            None
# 26              $7.9M          2007            None
# 27                 $0          2008            None
# 28                 $0          2007            None
# 29             $1.15M          2007            None
# ..                ...           ...             ...
# 70              $2.5M          2007            None
# 71                 $0          2007            None
# 72             $10.2M          2007            None
# 72             $10.2M          2007            None
# 73                 $0          2007            None
# 74                 $0          2007            None
# 75              $2.5M          2007            None
# 76                 $0          2007            None
# 77              $600k          2007            None
# 78             $68.5M          2007            None
# 79                 $0          2007            None
# 80              $5.6M          2007            None
# 81                 $0          2007            None
# 82                 $0          2007            None
# 83              $500k          2007            None
# 84             $19.4M          2007            None
# 85                 $0          2007            None
# 86             $14.5M          2012            None
# 87                 $0          2007            None
# 87                 $0          2007            None
# 88                 $0          2008            None
# 89              $500k          2007            None
# 90              £250k          2007            None
# 91                 $0          2007            None
# 92                 $0          2007            None
# 93             $13.5M          2007            None
# 94                 $0          2008            None
# 95             $1.51M          2007            None
# 96               $13M          2007            None
# 78  [{'description': 'HQ', 'address1': '25 Corpora...  42.524527  -71.137784
# 79  [{'description': None, 'address1': '510 Thorna...  40.565602  -74.331811
# 80  [{'description': '', 'address1': '55 Broad Str...  37.402802 -122.117418
# 81  [{'description': None, 'address1': '', 'addres...  33.994162 -118.463710
# 82  [{'description': None, 'address1': None, 'addr...  40.797364  -73.977850
# 83  [{'description': None, 'address1': '579 Valenc...  37.763652 -122.421778
# 84  [{'description': '', 'address1': '1011 Western...  47.639901 -122.191427
# 85  [{'description': None, 'address1': '101 N Wack...  41.883551  -87.636411
# 86  [{'description': None, 'address1': None, 'addr...  37.798853 -122.398599
# 87  [{'description': '', 'address1': '', 'address2...  40.521502  -74.275771
# 87  [{'description': '', 'address1': '', 'address2...  32.718834 -117.163841
# 88  [{'description': '', 'address1': 'U vodarny 2'...  49.225902   16.569282
# 89  [{'description': None, 'address1': None, 'addr...  37.090240  -95.712891
# 90  [{'description': '', 'address1': '123 Whitecro...  51.522413   -0.092690
# 91  [{'description': '', 'address1': '', 'address2...  37.090240  -95.712891
# 92  [{'description': None, 'address1': '12459 W 84...  39.851338 -105.139804
# 93  [{'description': '', 'address1': '50 Beale St....  37.789129 -122.402028
# 94  [{'description': None, 'address1': '1832 Frank...  34.031764 -118.461884
# 95  [{'description': '', 'address1': 'Pier 33 Sout...  37.290603 -121.931785
# 96  [{'description': None, 'address1': '', 'addres...  37.775196 -122.419204
# 97  [{'description': 'West Coast', 'address1': '25...  37.788266 -122.403865
#
#                                               oficina  total_USD_raised
# 0   {'type': 'Point', 'coordinates': [-122.404052,...          25800000
# 1   {'type': 'Point', 'coordinates': [-73.985506, ...           5580000
# 2   {'type': 'Point', 'coordinates': [-118.487267,...          21000000
# 3   {'type': 'Point', 'coordinates': [-73.995625, ...          14700000
# 4   {'type': 'Point', 'coordinates': [-74.3372, 40...          24000000
# 5   {'type': 'Point', 'coordinates': [-122.397224,...                 0
# 6   {'type': 'Point', 'coordinates': [-119.306607,...            100000
# 7   {'type': 'Point', 'coordinates': [-119.306607,...          12700000
# 8   {'type': 'Point', 'coordinates': [4.8948623, 5...           1000000
# 9   {'type': 'Point', 'coordinates': [-122.02421, ...                 0
# 10  {'type': 'Point', 'coordinates': [-122.511687,...                 0
# 11  {'type': 'Point', 'coordinates': [-122.419204,...          16000000
# 12  {'type': 'Point', 'coordinates': [-122.420903,...                 0
# 13  {'type': 'Point', 'coordinates': [-122.392142,...           8500000
# 14  {'type': 'Point', 'coordinates': [-122.417928,...                 0
# 15  {'type': 'Point', 'coordinates': [-122.073003,...            315000
# 16  {'type': 'Point', 'coordinates': [-46.679287, ...            300000
# 17  {'type': 'Point', 'coordinates': [-74.761403, ...           1310000
# 18  {'type': 'Point', 'coordinates': [-122.1879633...           4800000
# 19  {'type': 'Point', 'coordinates': [-122.3229235...           8500000
# 20  {'type': 'Point', 'coordinates': [-105.2762236...            415000
# 21  {'type': 'Point', 'coordinates': [-105.276843,...           1920000
# 22  {'type': 'Point', 'coordinates': [-71.05781, 4...          18300000
# 23  {'type': 'Point', 'coordinates': [-122.397593,...           8000000
# 24  {'type': 'Point', 'coordinates': [-118.495025,...           4000000
# 25  {'type': 'Point', 'coordinates': [-0.1418973, ...           4456327
# 26  {'type': 'Point', 'coordinates': [-71.104329, ...           7900000
# 27  {'type': 'Point', 'coordinates': [-122.151158,...                 0
# 28  {'type': 'Point', 'coordinates': [-122.419204,...                 0
# 29  {'type': 'Point', 'coordinates': [-122.3276962...           1150000
# ..                                                ...               ...
# 70  {'type': 'Point', 'coordinates': [-80.058401, ...           2500000
# 71  {'type': 'Point', 'coordinates': [-74.453466, ...                 0
# 72  {'type': 'Point', 'coordinates': [-95.712891, ...          10200000
# 72  {'type': 'Point', 'coordinates': [-122.4194155...          10200000
# 73  {'type': 'Point', 'coordinates': [-95.712891, ...                 0
# 74  {'type': 'Point', 'coordinates': [-73.996122, ...                 0
# 75  {'type': 'Point', 'coordinates': [34.7595, 32....           2500000
# 76  {'type': 'Point', 'coordinates': [-122.120938,...                 0
# 77  {'type': 'Point', 'coordinates': [-95.49158, 2...            600000
# 78  {'type': 'Point', 'coordinates': [-71.137784, ...          68500000
# 79  {'type': 'Point', 'coordinates': [-74.331811, ...                 0
# 80  {'type': 'Point', 'coordinates': [-122.117418,...           5600000
# 81  {'type': 'Point', 'coordinates': [-118.46371, ...                 0
# 82  {'type': 'Point', 'coordinates': [-73.97785, 4...                 0
# 83  {'type': 'Point', 'coordinates': [-122.421778,...            500000
# 84  {'type': 'Point', 'coordinates': [-122.1914274...          19400000
# 85  {'type': 'Point', 'coordinates': [-87.636411, ...                 0
# 86  {'type': 'Point', 'coordinates': [-122.398599,...          14500000
# 87  {'type': 'Point', 'coordinates': [-74.275771, ...                 0
# 87  {'type': 'Point', 'coordinates': [-117.163841,...                 0
# 88  {'type': 'Point', 'coordinates': [16.5692822, ...                 0
# 89  {'type': 'Point', 'coordinates': [-95.712891, ...            500000
# 90  {'type': 'Point', 'coordinates': [-0.0926903, ...            200374
# 91  {'type': 'Point', 'coordinates': [-95.712891, ...                 0
# 92  {'type': 'Point', 'coordinates': [-105.139804,...                 0
# 93  {'type': 'Point', 'coordinates': [-122.4020276...          13500000
# 94  {'type': 'Point', 'coordinates': [-118.461884,...                 0
# 95  {'type': 'Point', 'coordinates': [-121.9317853...           1510000
# 96  {'type': 'Point', 'coordinates': [-122.419204,...          13000000
# 97  {'type': 'Point', 'coordinates': [-122.403865,...           3150000
#
# [100 rows x 13 columns]

# %%
#reshape columns and get dimensions
df_concat = df_concat [['name','office','lat','long','oficina','category_code','number_of_employees','total_USD_raised','founded_year','deadpooled_year']]
df_concat.shape
# Out:
# (2292, 10)

# %%
#export json

df_concat.to_json('offices1.json', orient='records')
