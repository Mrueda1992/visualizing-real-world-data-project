# %%
from pymongo import MongoClient
import pandas as pd
import json
import folium
from folium import plugins
import os
from dotenv import load_dotenv
load_dotenv()
import requests as res 

client = MongoClient('mongodb://localhost:27017/')
db = client.company

# %%
data = db.geoqueries_OK.find()

# %%
df = pd.DataFrame(data)

# %%
df.shape
# Out:
# (105, 9)

# %%
m = folium.Map([41.8781, -87.6298],zoom_start=11)

# %%
stationArr = df[['lat','long']].as_matrix().tolist()
for index, row in df.iterrows():
    folium.CircleMarker([row['lat'], row['long']],
                       radius=15,
                       popup=row['name'],
                       fill_color="D2N55B").add_to(m)

m.add_child(plugins.HeatMap(stationArr, radius=20))
# Out:
# /Users/marcojoseruedaaguila/miniconda3/envs/ironhack/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def findNear(coord, radio_max_meters = 1000):
        query =  db.geoqueries_OK.find({"oficina": 
            {"$near": 
            {"$geometry":coord,
            "$maxDistance": radio_max_meters}}})
        return query
        
radio_max_meters=1000

num_offices= df['oficina'].apply(lambda x: list(findNear(x, radio_max_meters))) 
#value = documents['total_USD_raised']

# %%
num_offices[0]
# Out:
# [{'_id': ObjectId('5d271b52ba9f1bf3ba308865'),
#   'name': 'Mahalo',
#   'category_code': 'web',
#   'founded_year': 2007,
#   'lat': 34.017606,
#   'long': -118.487267,
#   'office': {'description': '',
#    'address1': '3525 Eastham Dr.',
#    'address2': '',
#    'zip_code': '90232',
#    'city': 'Culver City',
#    'state_code': 'CA',
#    'country_code': 'USA',
#    'latitude': 34.017606,
#    'longitude': -118.487267},
#   'oficina': {'type': 'Point', 'coordinates': [-118.487267, 34.017606]},
#   'total_USD_raised': 21000000},
#  {'_id': ObjectId('5d271b52ba9f1bf3ba30886c'),
#   'name': 'Docstoc',
#   'category_code': 'web',
#   'founded_year': 2007,
#   'lat': 34.018275,
#   'long': -118.495025,
#   'office': {'description': '',
#    'address1': '409 S Santa Monica Blvd',
#    'address2': 'Suite 2A',
#    'zip_code': '90401',
#    'city': 'Santa Monica',
#    'state_code': 'CA',
#    'country_code': 'USA',
#    'latitude': 34.018275,
#    'longitude': -118.495025},
#   'oficina': {'type': 'Point', 'coordinates': [-118.495025, 34.018275]},
#   'total_USD_raised': 4000000}]

# %%
df['near_offices']= num_offices
df.head()
# Out:
#                         _id category_code  founded_year        lat  \
# 0  5d271b52ba9f1bf3ba308865           web          2007  34.017606
# 1  5d271b52ba9f1bf3ba308866           web          2007  37.269175
# 2  5d271b52ba9f1bf3ba308867           web          2007  52.374523
# 3  5d271b52ba9f1bf3ba308868   games_video          2007  40.801358
# 4  5d271b52ba9f1bf3ba308869           web          2007  40.010492
#
#          long          name  \
# 0 -118.487267        Mahalo
# 1 -119.306607      SodaHead
# 2    4.894862       Wakoopa
# 3  -74.337200  AdaptiveBlue
# 4 -105.276843      Filtrbox
#
#                                               office  \
# 0  {'description': '', 'address1': '3525 Eastham ...
# 1  {'description': '', 'address1': '16161 Ventura...
# 2  {'description': 'Arts & Crafts', 'address1': '...
# 3  {'description': '', 'address1': '131 Varick St...
# 4  {'description': 'HQ', 'address1': '325 Lytton ...
#
#                                              oficina  total_USD_raised  \
# 0  {'type': 'Point', 'coordinates': [-118.487267,...          21000000
# 1  {'type': 'Point', 'coordinates': [-119.306607,...          12700000
# 2  {'type': 'Point', 'coordinates': [4.8948623, 5...           1000000
# 3  {'type': 'Point', 'coordinates': [-74.3372, 40...          24000000
# 4  {'type': 'Point', 'coordinates': [-105.276843,...           1920000
#
#                                         near_offices
# 0  [{'_id': 5d271b52ba9f1bf3ba308865, 'name': 'Ma...
# 1  [{'_id': 5d271b52ba9f1bf3ba308866, 'name': 'So...
# 2  [{'_id': 5d271b52ba9f1bf3ba308867, 'name': 'Wa...
# 3  [{'_id': 5d271b52ba9f1bf3ba308868, 'name': 'Ad...
# 4  [{'_id': 5d271b52ba9f1bf3ba308869, 'name': 'Fi...

# %%
value_total=[]
for i in range(len(num_offices)):
    value_partial=[]
    for empresas in num_offices[i]:
        value_partial.append(empresas['total_USD_raised'])
    value_total.append(value_partial)
    total=[]
    for i in range(len(value_total)):
        total.append(sum(value_total[i]))
print(len(total))
# Out:
# 105

# %%
df['value_in_area'] = total
df.head()
# Out:
#                         _id category_code  founded_year        lat  \
# 0  5d271b52ba9f1bf3ba308865           web          2007  34.017606
# 1  5d271b52ba9f1bf3ba308866           web          2007  37.269175
# 2  5d271b52ba9f1bf3ba308867           web          2007  52.374523
# 3  5d271b52ba9f1bf3ba308868   games_video          2007  40.801358
# 4  5d271b52ba9f1bf3ba308869           web          2007  40.010492
#
#          long          name  \
# 0 -118.487267        Mahalo
# 1 -119.306607      SodaHead
# 2    4.894862       Wakoopa
# 3  -74.337200  AdaptiveBlue
# 4 -105.276843      Filtrbox
#
#                                               office  \
# 0  {'description': '', 'address1': '3525 Eastham ...
# 1  {'description': '', 'address1': '16161 Ventura...
# 2  {'description': 'Arts & Crafts', 'address1': '...
# 3  {'description': '', 'address1': '131 Varick St...
# 4  {'description': 'HQ', 'address1': '325 Lytton ...
#
#                                              oficina  total_USD_raised  \
# 0  {'type': 'Point', 'coordinates': [-118.487267,...          21000000
# 1  {'type': 'Point', 'coordinates': [-119.306607,...          12700000
# 2  {'type': 'Point', 'coordinates': [4.8948623, 5...           1000000
# 3  {'type': 'Point', 'coordinates': [-74.3372, 40...          24000000
# 4  {'type': 'Point', 'coordinates': [-105.276843,...           1920000
#
#                                         near_offices  value_in_area
# 0  [{'_id': 5d271b52ba9f1bf3ba308865, 'name': 'Ma...       25000000
# 1  [{'_id': 5d271b52ba9f1bf3ba308866, 'name': 'So...       12700000
# 2  [{'_id': 5d271b52ba9f1bf3ba308867, 'name': 'Wa...        1000000
# 3  [{'_id': 5d271b52ba9f1bf3ba308868, 'name': 'Ad...       24000000
# 4  [{'_id': 5d271b52ba9f1bf3ba308869, 'name': 'Fi...        1920000

# %%
df = df[['name','category_code','lat','long','oficina','near_offices','value_in_area','total_USD_raised']]

# %%
df = df.sort_values(['value_in_area'], ascending=False)
df.head()
# Out:
#                  name category_code        lat        long  \
# 79  Green Apple Media           web  53.343830   -6.268947
# 57            Genbook           web  37.789902 -122.400779
# 39          99designs        design  37.795531 -122.400598
# 28               hulu   games_video  34.031276 -118.456806
# 62            Lolapps           web  37.787092 -122.399972
#
#                                               oficina  \
# 79  {'type': 'Point', 'coordinates': [-6.2689465, ...
# 57  {'type': 'Point', 'coordinates': [-122.4007791...
# 39  {'type': 'Point', 'coordinates': [-122.4005983...
# 28  {'type': 'Point', 'coordinates': [-118.456806,...
# 62  {'type': 'Point', 'coordinates': [-122.3999719...
#
#                                          near_offices  value_in_area  \
# 79  [{'_id': 5d271b52ba9f1bf3ba3088b4, 'name': 'Gr...      132000000
# 57  [{'_id': 5d271b52ba9f1bf3ba30889e, 'name': 'Ge...      123030000
# 39  [{'_id': 5d271b52ba9f1bf3ba30888c, 'name': '99...      117350000
# 28  [{'_id': 5d271b52ba9f1bf3ba308881, 'name': 'hu...      100000000
# 62  [{'_id': 5d271b52ba9f1bf3ba3088a3, 'name': 'Lo...       99430000
#
#     total_USD_raised
# 79         132000000
# 57           2200000
# 39          35000000
# 28         100000000
# 62           4000000

# %%
selected_office = folium.Map([34.031276, -118.4568068],zoom_start=11)
folium.Marker(location= [34.031276,-118.4568068], popup = df.iloc[28]['name'], icon=folium.Icon(icon='home', color='red')).add_to(selected_office)
selected_office
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Are kindergartens around our future office?

with open("../tokens.txt") as file:
    data = file.read()
kinderlist = []    
r1 = res.get("https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=34.031276,-118.456806&rankby=distance&type=school&key={}&name=kindergarten".format(data))
result = r1.json()
print(result)
'''
for i in range(len(result)):
    x = (result['results'][i]['name'],
          result['results'][i]['geometry']['location'],
          result['results'][i]['rating'])
    
    for guarderia in x:
        kinderlist.append(guarderia)
        
'''
# Out:
# {'error_message': 'This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console.', 'html_attributions': [], 'results': [], 'status': 'REQUEST_DENIED'}
# "\nfor i in range(len(result)):\n    x = (result['results'][i]['name'],\n          result['results'][i]['geometry']['location'],\n          result['results'][i]['rating'])\n    \n    for guarderia in x:\n        kinderlist.append(guarderia)\n        \n"

# %%
# result[0].get('name'), result[0].get('geometry'), result[0].get('rating')

'''
kinders = result.get('results')



df_kinds = pd.DataFrame(kinders)
df_kinds = df_kinds[['name','geometry','rating']]

get_lat = []
get_long = []
for key in df_kinds['geometry']:
    get_lat.append(key['location']['lat'])
    get_long.append(key['location']['lng'])



df_kinds['latitude'] = get_lat
df_kinds['longitude'] = get_long
    
df_kinds = df_kinds[['name','latitude','longitude','rating']]
'''
# Out:
# "\nkinders = result.get('results')\n\n\n\ndf_kinds = pd.DataFrame(kinders)\ndf_kinds = df_kinds[['name','geometry','rating']]\n\nget_lat = []\nget_long = []\nfor key in df_kinds['geometry']:\n    get_lat.append(key['location']['lat'])\n    get_long.append(key['location']['lng'])\n\n\n\ndf_kinds['latitude'] = get_lat\ndf_kinds['longitude'] = get_long\n    \ndf_kinds = df_kinds[['name','latitude','longitude','rating']]\n"

# %%
hulu = [{"name":"hulu","latitude":34.031276,"longitude":-122.400598,"rating":"-"}]

df_kinds.append(hulu, ignore_index=True)
# Out:
#                                               name   latitude   longitude  \
# 0                                  Wildwood School  34.033862 -118.451536
# 1                       Little Dolphins By the Sea  34.030710 -118.463585
# 2              Stratford School - West Los Angeles  34.036454 -118.450855
# 3                      Brawerman Elementary School  34.035329 -118.448295
# 4                                 Kigala Preschool  34.023992 -118.461357
# 5                          Edison Language Academy  34.024211 -118.465045
# 6            Southern California Montessori School  34.038239 -118.466672
# 7   Citizens of the World Charter School Mar Vista  34.031943 -118.442638
# 8                          Grant Elementary School  34.019178 -118.461745
# 9                Richland Avenue Elementary School  34.028370 -118.440229
# 10                   Nora Sterry Elementary School  34.044380 -118.447159
# 11                            St. Sebastian School  34.046820 -118.455552
# 12                      McKinley Elementary School  34.031782 -118.477018
# 13                    Crossroads Elementary School  34.022613 -118.478012
# 14                                The First School  34.013165 -118.465985
# 15                               Cassidy Preschool  34.032448 -118.481331
# 16                         Westside Waldorf School  34.024223 -118.483587
# 17                     Mar Vista Elementary School  34.016075 -118.434347
# 18                      Franklin Elementary School  34.039575 -118.485465
# 19                               WorldSpeak School  34.052145 -118.439371
# 20                                            hulu  34.031276 -122.400598
#
#    rating
# 0     4.9
# 1       0
# 2       0
# 3       5
# 4     3.3
# 5     4.4
# 6       5
# 7     4.4
# 8       4
# 9     4.1
# 10    3.6
# 11    4.4
# 12    4.3
# 13    3.8
# 14      0
# 15      5
# 16      5
# 17    4.9
# 18    4.1
# 19    2.3
# 20      -

# %%
m = folium.Map([34.031276, -118.456806], zoom_start=11)
tooltip= "Hulu heaquarters"
folium.Marker([34.031276, -118.456806], popup= 'Hulu headquarters', tooltip=tooltip).add_to(m)

# %%
#and Starbucks?

r2 = res.get("https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=34.031276,-118.456806&radius=400&type=cafe&key={}&name=starbucks".format(data))

b = r2.json()

starbucks = b.get('results')
df_starbucks = pd.DataFrame(starbucks)
df_starbucks = df_starbucks[['name','geometry','rating']]
df_starbucks.head(100)
# Out:
#                          name  \
# 0  The Coffee Bean & Tea Leaf
#
#                                             geometry  rating
# 0  {'location': {'lat': 34.032773, 'lng': -118.45...     4.4

# %%
#Night clubs?

r3 = res.get("https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=34.031276,-118.456806&radius=1000&type=night_club&key={}".format(data))
clubs = r3.json()

night_clubs = clubs.get('results')
df_clubs = pd.DataFrame(night_clubs)
df_clubs = df_clubs[['name','geometry','rating']]
df_clubs.head(100)
# Out:
#                name                                           geometry  rating
# 0       The Arsenal  {'location': {'lat': 34.029555, 'lng': -118.44...     4.4
# 1      Silver Reign  {'location': {'lat': 34.0329428, 'lng': -118.4...     3.5
# 2   The Jazz Bakery  {'location': {'lat': 34.031309, 'lng': -118.46...     4.0
# 3  Gentlemen's club  {'location': {'lat': 34.0330487, 'lng': -118.4...     3.6

# %%
#Vegans

r4 = res.get("https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=34.031276,-118.456806&radius=500&type=night_club&key={}".format(data))
vegans = r4.json()
vegan_rests = vegans.get('results')
df_vegans = pd.DataFrame(vegan_rests)
df_vegans = df_vegans[['name','geometry','rating']]
df_vegans.head(100)
# Out:
#                name                                           geometry  rating
# 0      Silver Reign  {'location': {'lat': 34.0329428, 'lng': -118.4...     3.5
# 1   The Jazz Bakery  {'location': {'lat': 34.031309, 'lng': -118.46...     4.0
# 2  Gentlemen's club  {'location': {'lat': 34.0330487, 'lng': -118.4...     3.6
