# %%
from pymongo import MongoClient
import pandas as pd
import re
import requests
import json


client = MongoClient('mongodb://localhost:27017/')
db = client.company

# %%
#filter companies that have coordinates

query= db.company.find({
    "$and":
    [{"deadpooled_year":None},
     {"number_of_employees":{"$ne":None}},
     {"founded_year":{"$gte":2007}},
     {"offices.longitude":{"$exists":True}},
     {"offices.latitude":{"$ne":None}},
     {"offices.longitude":{"$ne":None}},
     {"offices.longitude":{"$exists":True}
     }
    ]
}
)

# %%
print(query)
# Out:
# <pymongo.cursor.Cursor object at 0x1442f0710>

# %%
with_coords = pd.DataFrame(query)
with_coords.shape
# Out:
# (2152, 42)

# %%
#new dataframe with filtered columns

with_coords2 = with_coords[['_id','name','number_of_employees','category_code','offices','founded_year','ipo','funding_rounds','total_money_raised','investments','deadpooled_year','partners']]
with_coords2.head(100)
with_coords2.shape
# Out:
# (2152, 12)

# %%
get_offices= pd.DataFrame(with_coords['offices'].tolist()).stack().reset_index(level=1, drop=True)
office = get_offices.rename('office')

office.head()
# Out:
# 0    {'description': 'HQ', 'address1': '539 Bryant ...
# 1    {'description': None, 'address1': '', 'address...
# 2    {'description': '', 'address1': '3525 Eastham ...
# 3    {'description': 'Livestream HQ', 'address1': '...
# 4    {'description': '', 'address1': '131 Varick St...
# Name: office, dtype: object

# %%
df_clean= with_coords2.merge(office, left_index= True, right_index=True)

df_clean = df_clean[['name','number_of_employees','category_code','office','ipo','total_money_raised','founded_year','deadpooled_year','partners']]
df_clean.head()
# Out:
#            name  number_of_employees category_code  \
# 0        Scribd                   50          news
# 1       MeetMoi                   15        social
# 2        Mahalo                   40           web
# 3    Livestream                  120   games_video
# 4  AdaptiveBlue                   15   games_video
#
#                                               office   ipo total_money_raised  \
# 0  {'description': 'HQ', 'address1': '539 Bryant ...  None             $25.8M
# 1  {'description': None, 'address1': '', 'address...  None             $5.58M
# 2  {'description': '', 'address1': '3525 Eastham ...  None               $21M
# 3  {'description': 'Livestream HQ', 'address1': '...  None             $14.7M
# 4  {'description': '', 'address1': '131 Varick St...  None               $24M
#
#    founded_year deadpooled_year partners
# 0          2007            None       []
# 1          2007            None       []
# 2          2007            None       []
# 3          2007            None       []
# 4          2007            None       []

# %%
def getOffices(offices):
    offices = df_clean['office']
    principal = None
    for record in offices:     
        return {
            "lat": record['latitude'],
            "long": record['longitude']}
            

offices = df_clean[['office']].apply(getOffices, result_type="expand", axis=1)
offices.head()
# Out:
#          lat        long
# 0  37.789634 -122.404052
# 1  37.789634 -122.404052
# 2  37.789634 -122.404052
# 3  37.789634 -122.404052
# 4  37.789634 -122.404052

# %%
df_concat = pd.concat([df_clean,offices], axis=1)
df_concat.head()
# Out:
#            name  number_of_employees category_code  \
# 0        Scribd                   50          news
# 1       MeetMoi                   15        social
# 2        Mahalo                   40           web
# 3    Livestream                  120   games_video
# 4  AdaptiveBlue                   15   games_video
#
#                                               office   ipo total_money_raised  \
# 0  {'description': 'HQ', 'address1': '539 Bryant ...  None             $25.8M
# 1  {'description': None, 'address1': '', 'address...  None             $5.58M
# 2  {'description': '', 'address1': '3525 Eastham ...  None               $21M
# 3  {'description': 'Livestream HQ', 'address1': '...  None             $14.7M
# 4  {'description': '', 'address1': '131 Varick St...  None               $24M
#
#    founded_year deadpooled_year partners        lat        long
# 0          2007            None       []  37.789634 -122.404052
# 1          2007            None       []  37.789634 -122.404052
# 2          2007            None       []  37.789634 -122.404052
# 3          2007            None       []  37.789634 -122.404052
# 4          2007            None       []  37.789634 -122.404052

# %%
#Get API for exchange rate

url = "https://api.exchangeratesapi.io/latest?base=USD"
res = requests.get(url)
rates = res.json()
print(rates)
# Out:
# {'rates': {'CAD': 1.3124497992, 'HKD': 7.8097278001, 'ISK': 126.639892905, 'PHP': 51.3422579206, 'DKK': 6.6607764391, 'HUF': 290.4596162427, 'CZK': 22.7960731816, 'GBP': 0.8029897367, 'RON': 4.218206158, 'SEK': 9.490227577, 'IDR': 14130.0044622936, 'INR': 68.5238732709, 'BRL': 3.8063364569, 'RUB': 63.7221775993, 'HRK': 6.6000892459, 'JPY': 108.817492191, 'THB': 30.8353413655, 'CHF': 0.9939312807, 'EUR': 0.8924587238, 'MYR': 4.1419009371, 'BGN': 1.745470772, 'TRY': 5.6977242303, 'CNY': 6.8857652834, 'NOK': 8.6553324409, 'NZD': 1.5115573405, 'ZAR': 14.1643908969, 'USD': 1.0, 'MXN': 18.9046854083, 'SGD': 1.3609995538, 'AUD': 1.4425702811, 'ILS': 3.5675145025, 'KRW': 1182.55243195, 'PLN': 3.8045515395}, 'base': 'USD', 'date': '2019-07-09'}

# %%
#get currency types


x = []
for i in df_concat['total_money_raised']:
    y=re.findall("^\D+",i)
    if y not in x:
        x.append(y)
        
print(x)
# Out:
# [['$'], ['€'], ['£'], ['C$']]

# %%
def dropSpaces(currency):
    return currency.rstrip()
    

with_coords2['total_money_raised'] = with_coords2['total_money_raised'].apply(dropSpaces)
# Out:
# /usr/local/Cellar/ipython/7.5.0/libexec/vendor/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
def coinsValues_USD(currency):
    curr_float = float(re.search("\d*\.\d*|\d+", currency)[0])    
    if currency.endswith("M"):
        curr_float= curr_float*1000000
    if currency.endswith("B"):
        curr_float= curr_float*1000000000
    if currency.endswith("k"):
        curr_float= curr_float*1000
    if currency.startswith("€"): 
        curr_float = curr_float*rates['rates']['EUR']
    if currency.startswith("$"): 
        curr_float = curr_float
    if currency.startswith("£"):
        curr_float = curr_float*rates['rates']['GBP']
    if currency.startswith("C$"):
        curr_float = curr_float*rates['rates']['SEK']
    return int(curr_float)

df_concat['total_USD_raised'] = df_concat['total_money_raised'].apply(coinsValues_USD)


df_concat.head(100)
# Out:
#                name  number_of_employees    category_code  \
# 0            Scribd                   50             news
# 1           MeetMoi                   15           social
# 2            Mahalo                   40              web
# 3        Livestream                  120      games_video
# 4      AdaptiveBlue                   15      games_video
# 5            Pownce                    6              web
# 6   CriticalMetrics                    4              web
# 7          SodaHead                   25              web
# 8           Wakoopa                    8              web
# 9            coRank                    0              web
# 10        CrowdVine                   10              web
# 11          Seesmic                   13              web
# 12         Cofoundr                    0  network_hosting
# 13          GoingOn                   40         software
# 14           FeVote                    1              web
# 15           Buxfer                    4              web
# 16          boo-box                   50      advertising
# 17           Scrybe                   20       enterprise
# 18             Echo                   50       enterprise
# 19      Inneractive                    0      advertising
# 20      Socialthing                    5  network_hosting
# 21         Filtrbox                   14              web
# 22         Cloudant                   70       enterprise
# 23           Zivity                   16  network_hosting
# 24          Docstoc                   40              web
# 25         Seedcamp                    4          finance
# 26         LocaModa                    0      advertising
# 27          YouBeQB                    8      games_video
# 28       MicroPlace                   15              web
# 29           EyeJot                    5              web
# ..              ...                  ...              ...
# 70       divorce360                    6              web
# 71        eventsbot                   10              web
# 72         Uversity                   30           social
# 72         Uversity                   30           social
# 73            eBurl                    1              web
# 74           GoLark                    3              web
# 75        Flixwagon                   10           mobile
# 76       Picktastic                    2      games_video
# 77        CareFlash                    0              web
# 78           Acquia                  400       enterprise
# 79         LiveHire                    5      games_video
# 80       TravelMuse                   11              web
# 81           Driftr                    0              web
# 82           Orglex                    0              web
# 83            Mogad                    2  network_hosting
# 84        Livemocha                   35        education
# 85            Mpayy                    2        ecommerce
# 86        Widgetbox                   30            other
# 87     CheerOutLoud                    0              web
# 87     CheerOutLoud                    0              web
# 88          Webnode                   30  network_hosting
# 89           Frevvo                   10              web
# 90       UnLtdWorld                    4       enterprise
# 91           Boobik                    3              web
# 92        Blogonize                    1              web
# 93            Roost                   15         software
# 94      WonderHowTo                   12      games_video
# 95         clipsync                   28              web
# 96           Heroku                   80       enterprise
# 97          Lookery                    9              web
#
#                                                office   ipo  \
# 0   {'description': 'HQ', 'address1': '539 Bryant ...  None
# 1   {'description': None, 'address1': '', 'address...  None
# 2   {'description': '', 'address1': '3525 Eastham ...  None
# 3   {'description': 'Livestream HQ', 'address1': '...  None
# 4   {'description': '', 'address1': '131 Varick St...  None
# 5   {'description': '', 'address1': '1459 18th Str...  None
# 6   {'description': None, 'address1': None, 'addre...  None
# 7   {'description': '', 'address1': '16161 Ventura...  None
# 8   {'description': 'Arts & Crafts', 'address1': '...  None
# 9   {'description': None, 'address1': None, 'addre...  None
# 10  {'description': '', 'address1': '53 S Knoll Rd...  None
# 11  {'description': '', 'address1': '1550 Bryant S...  None
# 12  {'description': None, 'address1': None, 'addre...  None
# 13  {'description': 'GoingOn Networks, Inc.', 'add...  None
# 14  {'description': '', 'address1': '', 'address2'...  None
# 15  {'description': '', 'address1': '', 'address2'...  None
# 16  {'description': 'boo-land', 'address1': 'Av. F...  None
# 17  {'description': '', 'address1': '181 Fremont S...  None
# 18  {'description': 'headquarter', 'address1': '17...  None
# 19  {'description': '', 'address1': '300 S Ellswor...  None
# 20  {'description': 'HQ', 'address1': '1050 Walnut...  None
# 21  {'description': 'HQ', 'address1': '325 Lytton ...  None
# 22  {'description': '', 'address1': '129 South Str...  None
# 23  {'description': '', 'address1': '329 Bryant St...  None
# 24  {'description': '', 'address1': '409 S Santa M...  None
# 25  {'description': '', 'address1': '8 Clifford St...  None
# 26  {'description': 'HQ', 'address1': 'One Broadwa...  None
# 27  {'description': None, 'address1': None, 'addre...  None
# 28  {'description': '', 'address1': '', 'address2'...  None
# 29  {'description': '', 'address1': '315 5th Ave S...  None
# ..                                                ...   ...
# 70  {'description': None, 'address1': '760 US High...  None
# 71  {'description': None, 'address1': '571 Bucking...  None
# 72  {'description': None, 'address1': None, 'addre...  None
# 72  {'description': None, 'address1': None, 'addre...  None
# 73  {'description': None, 'address1': '', 'address...  None
# 74  {'description': None, 'address1': '', 'address...  None
# 75  {'description': None, 'address1': None, 'addre...  None
# 76  {'description': None, 'address1': None, 'addre...  None
# 77  {'description': 'CareFlash LLC', 'address1': '...  None
# 78  {'description': 'HQ', 'address1': '25 Corporat...  None
# 79  {'description': None, 'address1': '510 Thornal...  None
# 80  {'description': '', 'address1': '55 Broad Stre...  None
# 81  {'description': None, 'address1': '', 'address...  None
# 82  {'description': None, 'address1': None, 'addre...  None
# 83  {'description': None, 'address1': '579 Valenci...  None
# 84  {'description': '', 'address1': '1011 Western ...  None
# 85  {'description': None, 'address1': '101 N Wacke...  None
# 86  {'description': None, 'address1': None, 'addre...  None
# 87  {'description': '', 'address1': '', 'address2'...  None
# 87  {'description': '', 'address1': '', 'address2'...  None
# 88  {'description': '', 'address1': 'U vodarny 2',...  None
# 89  {'description': None, 'address1': None, 'addre...  None
# 90  {'description': '', 'address1': '123 Whitecros...  None
# 91  {'description': '', 'address1': '', 'address2'...  None
# 92  {'description': None, 'address1': '12459 W 84t...  None
# 93  {'description': '', 'address1': '50 Beale St. ...  None
# 94  {'description': None, 'address1': '1832 Frankl...  None
# 95  {'description': '', 'address1': 'Pier 33 South...  None
# 96  {'description': None, 'address1': '', 'address...  None
# 97  {'description': 'West Coast', 'address1': '25 ...  None
#
#    total_money_raised  founded_year deadpooled_year  \
# 0              $25.8M          2007            None
# 1              $5.58M          2007            None
# 2                $21M          2007            None
# 3              $14.7M          2007            None
# 4                $24M          2007            None
# 5                  $0          2007            None
# 6               $100k          2007            None
# 7              $12.7M          2007            None
# 8                 $1M          2007            None
# 9                  $0          2007            None
# 10                 $0          2007            None
# 11               $16M          2007            None
# 12                 $0          2007            None
# 13              $8.5M          2008            None
# 14                 $0          2007            None
# 15              $315k          2007            None
# 16              $300k          2007            None
# 17             $1.31M          2007            None
# 18              $4.8M          2007            None
# 19              $8.5M          2007            None
# 20              $415k          2007            None
# 21             $1.92M          2007            None
# 22             $18.3M          2008            None
# 23                $8M          2007            None
# 24                $4M          2007            None
# 25                €5M          2007            None
# 26              $7.9M          2007            None
# 27                 $0          2008            None
# 28                 $0          2007            None
# 29             $1.15M          2007            None
# ..                ...           ...             ...
# 70              $2.5M          2007            None
# 71                 $0          2007            None
# 72             $10.2M          2007            None
# 72             $10.2M          2007            None
# 73                 $0          2007            None
# 74                 $0          2007            None
# 75              $2.5M          2007            None
# 76                 $0          2007            None
# 77              $600k          2007            None
# 78             $68.5M          2007            None
# 79                 $0          2007            None
# 80              $5.6M          2007            None
# 81                 $0          2007            None
# 82                 $0          2007            None
# 83              $500k          2007            None
# 84             $19.4M          2007            None
# 85                 $0          2007            None
# 86             $14.5M          2012            None
# 87                 $0          2007            None
# 87                 $0          2007            None
# 88                 $0          2008            None
# 89              $500k          2007            None
# 90              £250k          2007            None
# 91                 $0          2007            None
# 92                 $0          2007            None
# 93             $13.5M          2007            None
# 94                 $0          2008            None
# 95             $1.51M          2007            None
# 96               $13M          2007            None
# 97             $3.15M          2007            None
#
#                                              partners        lat        long  \
# 0                                                  []  37.789634 -122.404052
# 1                                                  []  37.789634 -122.404052
# 2                                                  []  37.789634 -122.404052
# 3                                                  []  37.789634 -122.404052
# 4                                                  []  37.789634 -122.404052
# 5                                                  []  37.789634 -122.404052
# 6                                                  []  37.789634 -122.404052
# 7                                                  []  37.789634 -122.404052
# 8                                                  []  37.789634 -122.404052
# 9                                                  []  37.789634 -122.404052
# 10                                                 []  37.789634 -122.404052
# 11                                                 []  37.789634 -122.404052
# 12                                                 []  37.789634 -122.404052
# 13                                                 []  37.789634 -122.404052
# 14                                                 []  37.789634 -122.404052
# 15                                                 []  37.789634 -122.404052
# 16  [{'partner_name': 'AngelList', 'homepage_url':...  37.789634 -122.404052
# 17                                                 []  37.789634 -122.404052
# 18  [{'partner_name': 'AngelList', 'homepage_url':...  37.789634 -122.404052
# 19                                                 []  37.789634 -122.404052
# 20                                                 []  37.789634 -122.404052
# 21                                                 []  37.789634 -122.404052
# 22                                                 []  37.789634 -122.404052
# 23                                                 []  37.789634 -122.404052
# 24  [{'partner_name': 'AngelList', 'homepage_url':...  37.789634 -122.404052
# 25                                                 []  37.789634 -122.404052
# 26                                                 []  37.789634 -122.404052
# 27                                                 []  37.789634 -122.404052
# 28                                                 []  37.789634 -122.404052
# 29                                                 []  37.789634 -122.404052
# ..                                                ...        ...         ...
# 70                                                 []  37.789634 -122.404052
# 71                                                 []  37.789634 -122.404052
# 72                                                 []  37.789634 -122.404052
# 72                                                 []  37.789634 -122.404052
# 73                                                 []  37.789634 -122.404052
# 74                                                 []  37.789634 -122.404052
# 75                                                 []  37.789634 -122.404052
# 76                                                 []  37.789634 -122.404052
# 77                                                 []  37.789634 -122.404052
# 78                                                 []  37.789634 -122.404052
# 79                                                 []  37.789634 -122.404052
# 80                                                 []  37.789634 -122.404052
# 81                                                 []  37.789634 -122.404052
# 82                                                 []  37.789634 -122.404052
# 83                                                 []  37.789634 -122.404052
# 84                                                 []  37.789634 -122.404052
# 85                                                 []  37.789634 -122.404052
# 86                                                 []  37.789634 -122.404052
# 87                                                 []  37.789634 -122.404052
# 87                                                 []  37.789634 -122.404052
# 88                                                 []  37.789634 -122.404052
# 89                                                 []  37.789634 -122.404052
# 90                                                 []  37.789634 -122.404052
# 91                                                 []  37.789634 -122.404052
# 92                                                 []  37.789634 -122.404052
# 93                                                 []  37.789634 -122.404052
# 94                                                 []  37.789634 -122.404052
# 95                                                 []  37.789634 -122.404052
# 96                                                 []  37.789634 -122.404052
# 97                                                 []  37.789634 -122.404052
#
#     total_USD_raised
# 0           25800000
# 1            5580000
# 2           21000000
# 3           14700000
# 4           24000000
# 5                  0
# 6             100000
# 7           12700000
# 8            1000000
# 9                  0
# 10                 0
# 11          16000000
# 12                 0
# 13           8500000
# 14                 0
# 15            315000
# 16            300000
# 17           1310000
# 18           4800000
# 19           8500000
# 20            415000
# 21           1920000
# 22          18300000
# 23           8000000
# 24           4000000
# 25           4462293
# 26           7900000
# 27                 0
# 28                 0
# 29           1150000
# ..               ...
# 70           2500000
# 71                 0
# 72          10200000
# 72          10200000
# 73                 0
# 74                 0
# 75           2500000
# 76                 0
# 77            600000
# 78          68500000
# 79                 0
# 80           5600000
# 81                 0
# 82                 0
# 83            500000
# 84          19400000
# 85                 0
# 86          14500000
# 87                 0
# 87                 0
# 88                 0
# 89            500000
# 90            200747
# 91                 0
# 92                 0
# 93          13500000
# 94                 0
# 95           1510000
# 96          13000000
# 97           3150000
#
# [100 rows x 12 columns]

# %%
df_concat[['name','office','lat','long','number_of_employees','category_code','founded_year','ipo','total_USD_raised','deadpooled_year']]
df_concat.shape
# Out:
# (2292, 12)

# %%
#export json
